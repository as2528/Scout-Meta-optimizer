# %%
"""scout_opt_cifar10.py

Quick‑and‑dirty *large(-ish)* demo of the scout–guided optimizer on CIFAR‑10.

• Dataset  : CIFAR‑10 (50 k train / 10 k test, 32×32 colour)
• Model    : lightweight CNN (~0.6 M params)
• Baseline : Adam
• ScoutOpt : wraps Adam, periodically probes 2 directions
             (current grad + one random orthogonal) with
             a 1‑step look‑ahead on the same mini‑batch.

Run from a Jupyter cell (accepts the stray -f arg) or from CLI:
    python scout_opt_cifar10.py --gpu  
-------------------------------------------------------"""

import argparse, time, pathlib, random, sys
from typing import List

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# ------------------------------------------------------------------ #
#  1. A small-ish CNN                                                #
# ------------------------------------------------------------------ #
class SmallCNN(nn.Module):
    def __init__(self, n_classes: int = 10):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.pool  = nn.MaxPool2d(2, 2)
        self.fc1   = nn.Linear(256 * 4 * 4, 256)
        self.fc2   = nn.Linear(256, n_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # 32→16
        x = self.pool(F.relu(self.conv2(x)))  # 16→8
        x = self.pool(F.relu(self.conv3(x)))  # 8 →4
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# ------------------------------------------------------------------ #
#  2. Scout‑guided Optimizer                                         #
# ------------------------------------------------------------------ #
import torch
import torch.nn as nn
from typing import List

class ModifiedScoutOptimizer(torch.optim.Optimizer):
    """
    Extended Scout Optimizer with multi-step probes along ±orthogonal directions.
    Now supports walking 'scout_steps' forward in each direction before deciding.
    """

    def __init__(
        self,
        params,
        base_opt_cls,
        *,
        lr=3e-4,
        scout_every=100,
        scout_radius=5e-4,
        scout_steps=100,
        **base_kwargs
    ):
        param_list = list(params)
        self.base = base_opt_cls(param_list, lr=lr, **base_kwargs)
        super().__init__(param_list, defaults=dict(lr=lr))
        self.s_every = scout_every
        self.radius = scout_radius
        self.steps = scout_steps
        self._step_id = 0
        self._params = param_list

    @staticmethod
    @torch.no_grad()
    def _flatten(tensors: List[torch.Tensor]):
        return torch.cat([t.reshape(-1) for t in tensors])

    @torch.no_grad()
    def _apply_delta(self, vec_flat: torch.Tensor, coef: float):
        offset = 0
        for p in self._params:
            n = p.numel()
            p.add_(vec_flat[offset:offset+n].view_as(p), alpha=coef)
            offset += n

    @staticmethod
    @torch.no_grad()
    def _rand_orthogonal(base: torch.Tensor):
        r = torch.randn_like(base)
        proj = (r @ base) / (base @ base + 1e-12)
        ortho = r - proj * base
        return ortho / (ortho.norm() + 1e-12)

    @torch.no_grad()
    def _track_direction(self, direction: torch.Tensor, closure, max_steps: int):
        best_loss = float('inf')
        best_step = 0

        for i in range(1, max_steps + 1):
            self._apply_delta(direction, self.radius)
            loss = closure()
            if loss < best_loss:
                best_loss = loss
                best_step = i

        self._apply_delta(direction, -self.radius * best_step)
        return best_loss, direction, best_step

    def step(self, closure=None):
        if closure is None:
            raise RuntimeError("ModifiedScoutOptimizer needs a closure that returns loss and does backward()")

        loss = closure()
        self._step_id += 1

        if self._step_id % self.s_every == 0:
            grad_flat = self._flatten([p.grad for p in self._params])
            grad_norm = grad_flat.norm() + 1e-12
            grad_dir = grad_flat / grad_norm
            ortho_dir = self._rand_orthogonal(grad_dir)

            directions = [
                grad_dir,
                ortho_dir,
                -ortho_dir
            ]

            best_loss = loss.item()
            best_dir = None
            best_scale = 0

            for d in directions:
                tracked_loss, d_dir, d_steps = self._track_direction(d, closure, self.steps)
                if tracked_loss < best_loss:
                    best_loss = tracked_loss
                    best_dir = d_dir
                    best_scale = d_steps

            if best_dir is not None:
                new_grad = best_dir * grad_norm
                offset = 0
                for p in self._params:
                    n = p.numel()
                    p.grad.copy_(new_grad[offset:offset+n].view_as(p))
                    offset += n

        self.base.step()
        return loss


# ------------------------------------------------------------------ #
#  3. Training / evaluation loops                                    #
# ------------------------------------------------------------------ #
@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    tot_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        out = model(x)
        tot_loss += criterion(out, y).item() * x.size(0)
        pred = out.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return tot_loss / total, correct / total


def train_one_epoch(model, loader, criterion, opt, device, log_every=100):
    model.train()
    running = 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
    def closure():
        opt.base.zero_grad()
        # Clone the inputs to keep computation graph fresh for each probe
        x_cloned = x.detach().clone().requires_grad_(True)
        y_cloned = y.detach().clone()
        out = model(x_cloned)
        loss = criterion(out, y_cloned)
        loss.backward(retain_graph=True)
        return loss


        loss = opt.step(closure)
        running += loss.item()
        if (i + 1) % log_every == 0:
            print(f"  batch {i+1}/{len(loader)}  loss {running/log_every:.3f}")
            running = 0.0
# ------------------------------------------------------------------ #
#  4. Baseline Adam Check                                                     #
# ------------------------------------------------------------------ #


def run_baseline_adam(epochs=6, batch=128, lr=3e-4, results=None):
    print("\nBaseline: Adam")
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])
    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)
    train_loader = DataLoader(train_set, batch_size=batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,   shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=1e-4)

    for ep in range(1, epochs+1):
        print(f"\nEpoch {ep}/{epochs}")
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}")
        if results is not None:
            results['adam_loss'].append(val_loss)
            results['adam_acc'].append(val_acc)

# ------------------------------------------------------------------ #
#  5. Main                                                           #
# ------------------------------------------------------------------ #


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--epochs', type=int, default=50)
    parser.add_argument('--batch',  type=int, default=128)
    parser.add_argument('--lr',     type=float, default=3e-4)
    parser.add_argument('--scout_every',  type=int, default=100)
    parser.add_argument('--scout_radius', type=float, default=5e-4)
    parser.add_argument('--gpu', action='store_true')
    args, _ = parser.parse_known_args()

    device = torch.device('cuda' if args.gpu and torch.cuda.is_available() else 'cpu')
    print('Device:', device)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])

    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, batch_size=args.batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,       shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    opt = ModifiedScoutOptimizer(
        model.parameters(), optim.Adam,
        lr=args.lr,
        scout_every=args.scout_every,
        scout_radius=args.scout_radius,
        scout_steps=50,
        betas=(0.9, 0.999),
        weight_decay=1e-4
    )


    results = {'scout_loss': [], 'scout_acc': [], 'adam_loss': [], 'adam_acc': []}

    for ep in range(1, args.epochs+1):
        print(f"\nEpoch {ep}/{args.epochs}")
        start = time.time()
        train_one_epoch(model, train_loader, criterion, opt, device)
        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
        results['scout_loss'].append(val_loss)
        results['scout_acc'].append(val_acc)

    torch.save(model.state_dict(), "scout_cnn.pth")
    print("Model saved to scout_cnn.pth")

    run_baseline_adam(epochs=args.epochs, batch=args.batch, lr=args.lr, results=results)

    print("\nFinal comparison table:")
    for i in range(args.epochs):
        print(f"Epoch {i+1:>2}:  Scout acc = {results['scout_acc'][i]*100:.2f}%  |  Adam acc = {results['adam_acc'][i]*100:.2f}%")

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(results['scout_loss'], label='Scout Loss')
    plt.plot(results['adam_loss'],  label='Adam Loss')
    plt.legend()
    plt.title("Validation Loss")

    plt.subplot(1, 2, 2)
    plt.plot(results['scout_acc'], label='Scout Acc')
    plt.plot(results['adam_acc'],  label='Adam Acc')
    plt.legend()
    plt.title("Validation Accuracy")
    plt.tight_layout()
    plt.show()

if __name__ == '__main__':
    if sys.argv[0].endswith("ipykernel_launcher.py"):
        sys.argv = ['scout_opt_cifar10.py']
    main()
# Out:
# Device: cpu
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch 1/50
#   val_loss=2.305  val_acc=0.109  (28.8s)
#
# Epoch 2/50
#   val_loss=2.305  val_acc=0.109  (29.1s)
#
# Epoch 3/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 319
#     317 if sys.argv[0].endswith("ipykernel_launcher.py"):
#     318     sys.argv = ['scout_opt_cifar10.py']
# --> 319 main()
#
# Cell In[8], line 286, in main()
#     284 print(f"\nEpoch {ep}/{args.epochs}")
#     285 start = time.time()
# --> 286 train_one_epoch(model, train_loader, criterion, opt, device)
#     287 val_loss, val_acc = evaluate(model, test_loader, criterion, device)
#     288 print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
#
# Cell In[8], line 179, in train_one_epoch(model, loader, criterion, opt, device, log_every)
#     177 model.train()
#     178 running = 0.0
# --> 179 for i, (x, y) in enumerate(loader):
#     180     x, y = x.to(device), y.to(device)
#     181 def closure():
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\dataloader.py:440, in DataLoader.__iter__(self)
#     438     return self._iterator
#     439 else:
# --> 440     return self._get_iterator()
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\dataloader.py:388, in DataLoader._get_iterator(self)
#     386 else:
#     387     self.check_worker_number_rationality()
# --> 388     return _MultiProcessingDataLoaderIter(self)
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\dataloader.py:1038, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1031 w.daemon = True
#    1032 # NB: Process.start() actually take some time as it needs to
#    1033 #     start a process and pass the arguments over via a pipe.
#    1034 #     Therefore, we only add a worker to self._workers list after
#    1035 #     it started, so that we do not call .join() if program dies
#    1036 #     before it starts, and __del__ tries to join but will get:
#    1037 #     AssertionError: can only join a started process.
# -> 1038 w.start()
#    1039 self._index_queues.append(index_queue)
#    1040 self._workers.append(w)
#
# File ~\anaconda3\envs\pytorch_env\lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~\anaconda3\envs\pytorch_env\lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~\anaconda3\envs\pytorch_env\lib\multiprocessing\context.py:327, in SpawnProcess._Popen(process_obj)
#     324 @staticmethod
#     325 def _Popen(process_obj):
#     326     from .popen_spawn_win32 import Popen
# --> 327     return Popen(process_obj)
#
# File ~\anaconda3\envs\pytorch_env\lib\multiprocessing\popen_spawn_win32.py:93, in Popen.__init__(self, process_obj)
#      91 try:
#      92     reduction.dump(prep_data, to_child)
# ---> 93     reduction.dump(process_obj, to_child)
#      94 finally:
#      95     set_spawning_popen(None)
#
# File ~\anaconda3\envs\pytorch_env\lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:

# %%
"""scout_opt_cifar10.py

Quick‑and‑dirty *large(-ish)* demo of the scout–guided optimizer on CIFAR‑10.

• Dataset  : CIFAR‑10 (50 k train / 10 k test, 32×32 colour)
• Model    : lightweight CNN (~0.6 M params)
• Baseline : Adam
• ScoutOpt : wraps Adam, periodically probes 2 directions
             (current grad + one random orthogonal) with
             a 1‑step look‑ahead on the same mini‑batch.

Run from a Jupyter cell (accepts the stray -f arg) or from CLI:
    python scout_opt_cifar10.py --gpu  
-------------------------------------------------------"""

import argparse, time, pathlib, random, sys
from typing import List

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# ------------------------------------------------------------------ #
#  1. A small-ish CNN                                                #
# ------------------------------------------------------------------ #
class SmallCNN(nn.Module):
    def __init__(self, n_classes: int = 10):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.pool  = nn.MaxPool2d(2, 2)
        self.fc1   = nn.Linear(256 * 4 * 4, 256)
        self.fc2   = nn.Linear(256, n_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # 32→16
        x = self.pool(F.relu(self.conv2(x)))  # 16→8
        x = self.pool(F.relu(self.conv3(x)))  # 8 →4
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# ------------------------------------------------------------------ #
#  2. Scout‑guided Optimizer                                         #
# ------------------------------------------------------------------ #
import torch
import torch.nn as nn
from typing import List

class ModifiedScoutOptimizer(torch.optim.Optimizer):
    """
    Extended Scout Optimizer with multi-step probes along ±orthogonal directions.
    Now supports walking 'scout_steps' forward in each direction before deciding.
    """

    def __init__(
        self,
        params,
        base_opt_cls,
        *,
        lr=3e-4,
        scout_every=100,
        scout_radius=5e-4,
        scout_steps=100,
        **base_kwargs
    ):
        param_list = list(params)
        self.base = base_opt_cls(param_list, lr=lr, **base_kwargs)
        super().__init__(param_list, defaults=dict(lr=lr))
        self.s_every = scout_every
        self.radius = scout_radius
        self.steps = scout_steps
        self._step_id = 0
        self._params = param_list

    @staticmethod
    @torch.no_grad()
    def _flatten(tensors: List[torch.Tensor]):
        return torch.cat([t.reshape(-1) for t in tensors])

    @torch.no_grad()
    def _apply_delta(self, vec_flat: torch.Tensor, coef: float):
        offset = 0
        for p in self._params:
            n = p.numel()
            p.add_(vec_flat[offset:offset+n].view_as(p), alpha=coef)
            offset += n

    @staticmethod
    @torch.no_grad()
    def _rand_orthogonal(base: torch.Tensor):
        r = torch.randn_like(base)
        proj = (r @ base) / (base @ base + 1e-12)
        ortho = r - proj * base
        return ortho / (ortho.norm() + 1e-12)

    @torch.no_grad()
    def _track_direction(self, direction: torch.Tensor, closure, max_steps: int):
        best_loss = float('inf')
        best_step = 0

        for i in range(1, max_steps + 1):
            self._apply_delta(direction, self.radius)
            loss = closure()
            if loss < best_loss:
                best_loss = loss
                best_step = i

        self._apply_delta(direction, -self.radius * best_step)
        return best_loss, direction, best_step

    def step(self, closure=None):
        if closure is None:
            raise RuntimeError("ModifiedScoutOptimizer needs a closure that returns loss and does backward()")

        loss = closure()
        self._step_id += 1

        if self._step_id % self.s_every == 0:
            grad_flat = self._flatten([p.grad for p in self._params])
            grad_norm = grad_flat.norm() + 1e-12
            grad_dir = grad_flat / grad_norm
            ortho_dir = self._rand_orthogonal(grad_dir)

            directions = [
                grad_dir,
                ortho_dir,
                -ortho_dir
            ]

            best_loss = loss.item()
            best_dir = None
            best_scale = 0

            for d in directions:
                tracked_loss, d_dir, d_steps = self._track_direction(d, closure, self.steps)
                if tracked_loss < best_loss:
                    best_loss = tracked_loss
                    best_dir = d_dir
                    best_scale = d_steps

            if best_dir is not None:
                new_grad = best_dir * grad_norm
                offset = 0
                for p in self._params:
                    n = p.numel()
                    p.grad.copy_(new_grad[offset:offset+n].view_as(p))
                    offset += n

        self.base.step()
        return loss


# ------------------------------------------------------------------ #
#  3. Training / evaluation loops                                    #
# ------------------------------------------------------------------ #
@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    tot_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        out = model(x)
        tot_loss += criterion(out, y).item() * x.size(0)
        pred = out.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return tot_loss / total, correct / total


def train_one_epoch(model, loader, criterion, opt, device, log_every=100):
    model.train()
    running = 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)

        def closure():
            opt.base.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            return loss

        loss = opt.step(closure)
        running += loss.item()
        if (i + 1) % log_every == 0:
            print(f"  batch {i+1}/{len(loader)}  loss {running/log_every:.3f}")
            running = 0.0

# ------------------------------------------------------------------ #
#  4. Baseline Adam Check                                            #
# ------------------------------------------------------------------ #

def run_baseline_adam(epochs=6, batch=128, lr=3e-4, results=None):
    print("\nBaseline: Adam")
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])
    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)
    train_loader = DataLoader(train_set, batch_size=batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,   shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=1e-4)

    for ep in range(1, epochs+1):
        print(f"\nEpoch {ep}/{epochs}")
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}")
        if results is not None:
            results['adam_loss'].append(val_loss)
            results['adam_acc'].append(val_acc)

# ------------------------------------------------------------------ #
#  5. Main                                                           #
# ------------------------------------------------------------------ #

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--epochs', type=int, default=50)
    parser.add_argument('--batch',  type=int, default=128)
    parser.add_argument('--lr',     type=float, default=3e-4)
    parser.add_argument('--scout_every',  type=int, default=100)
    parser.add_argument('--scout_radius', type=float, default=5e-4)
    parser.add_argument('--gpu', action='store_true')
    args, _ = parser.parse_known_args()

    args.gpu = True  # Force GPU usage in Jupyter
    device = torch.device('cuda' if args.gpu and torch.cuda.is_available() else 'cpu')
    print('Using CUDA:', torch.cuda.is_available(), 'Device:', device)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])

    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, batch_size=args.batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,       shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    opt = ModifiedScoutOptimizer(
        model.parameters(), optim.Adam,
        lr=args.lr,
        scout_every=args.scout_every,
        scout_radius=args.scout_radius,
        scout_steps=50,
        betas=(0.9, 0.999),
        weight_decay=1e-4
    )

    results = {'scout_loss': [], 'scout_acc': [], 'adam_loss': [], 'adam_acc': []}

    for ep in range(1, args.epochs+1):
        print(f"\nEpoch {ep}/{args.epochs}")
        start = time.time()
        train_one_epoch(model, train_loader, criterion, opt, device)
        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
        results['scout_loss'].append(val_loss)
        results['scout_acc'].append(val_acc)

    torch.save(model.state_dict(), "scout_cnn.pth")
    print("Model saved to scout_cnn.pth")

    run_baseline_adam(epochs=args.epochs, batch=args.batch, lr=args.lr, results=results)

    print("\nFinal comparison table:")
    for i in range(args.epochs):
        print(f"Epoch {i+1:>2}:  Scout acc = {results['scout_acc'][i]*100:.2f}%  |  Adam acc = {results['adam_acc'][i]*100:.2f}%")

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(results['scout_loss'], label='Scout Loss')
    plt.plot(results['adam_loss'],  label='Adam Loss')
    plt.legend()
    plt.title("Validation Loss")

    plt.subplot(1, 2, 2)
    plt.plot(results['scout_acc'], label='Scout Acc')
    plt.plot(results['adam_acc'],  label='Adam Acc')
    plt.legend()
    plt.title("Validation Accuracy")
    plt.tight_layout()
    plt.show()

if __name__ == '__main__':
    if 'ipykernel' in sys.argv[0]:
        sys.argv = ['scout_opt_cifar10.py', '--gpu']
    main()
# Out:
# Using CUDA: True Device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch 1/50
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 315
#     313 if 'ipykernel' in sys.argv[0]:
#     314     sys.argv = ['scout_opt_cifar10.py', '--gpu']
# --> 315 main()
#
# Cell In[9], line 282, in main()
#     280 print(f"\nEpoch {ep}/{args.epochs}")
#     281 start = time.time()
# --> 282 train_one_epoch(model, train_loader, criterion, opt, device)
#     283 val_loss, val_acc = evaluate(model, test_loader, criterion, device)
#     284 print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
#
# Cell In[9], line 189, in train_one_epoch(model, loader, criterion, opt, device, log_every)
#     186     loss.backward()
#     187     return loss
# --> 189 loss = opt.step(closure)
#     190 running += loss.item()
#     191 if (i + 1) % log_every == 0:
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# Cell In[9], line 141, in ModifiedScoutOptimizer.step(self, closure)
#     138 best_scale = 0
#     140 for d in directions:
# --> 141     tracked_loss, d_dir, d_steps = self._track_direction(d, closure, self.steps)
#     142     if tracked_loss < best_loss:
#     143         best_loss = tracked_loss
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[9], line 109, in ModifiedScoutOptimizer._track_direction(self, direction, closure, max_steps)
#     107 for i in range(1, max_steps + 1):
#     108     self._apply_delta(direction, self.radius)
# --> 109     loss = closure()
#     110     if loss < best_loss:
#     111         best_loss = loss
#
# Cell In[9], line 186, in train_one_epoch.<locals>.closure()
#     184 out = model(x)
#     185 loss = criterion(out, y)
# --> 186 loss.backward()
#     187 return loss
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\autograd\__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\autograd\graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
"""scout_opt_cifar10.py

Quick‑and‑dirty *large(-ish)* demo of the scout–guided optimizer on CIFAR‑10.

• Dataset  : CIFAR‑10 (50 k train / 10 k test, 32×32 colour)
• Model    : lightweight CNN (~0.6 M params)
• Baseline : Adam
• ScoutOpt : wraps Adam, periodically probes 2 directions
             (current grad + one random orthogonal) with
             a 1‑step look‑ahead on the same mini‑batch.

Run from a Jupyter cell (accepts the stray -f arg) or from CLI:
    python scout_opt_cifar10.py --gpu  
-------------------------------------------------------"""

import argparse, time, pathlib, random, sys
from typing import List

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# ------------------------------------------------------------------ #
#  1. A small-ish CNN                                                #
# ------------------------------------------------------------------ #
class SmallCNN(nn.Module):
    def __init__(self, n_classes: int = 10):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.pool  = nn.MaxPool2d(2, 2)
        self.fc1   = nn.Linear(256 * 4 * 4, 256)
        self.fc2   = nn.Linear(256, n_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # 32→16
        x = self.pool(F.relu(self.conv2(x)))  # 16→8
        x = self.pool(F.relu(self.conv3(x)))  # 8 →4
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# ------------------------------------------------------------------ #
#  2. Scout‑guided Optimizer                                         #
# ------------------------------------------------------------------ #
import torch
import torch.nn as nn
from typing import List

class ModifiedScoutOptimizer(torch.optim.Optimizer):
    """
    Extended Scout Optimizer with multi-step probes along ±orthogonal directions.
    Now supports walking 'scout_steps' forward in each direction before deciding.
    """

    def __init__(
        self,
        params,
        base_opt_cls,
        *,
        lr=3e-4,
        scout_every=100,
        scout_radius=5e-4,
        scout_steps=100,
        **base_kwargs
    ):
        param_list = list(params)
        self.base = base_opt_cls(param_list, lr=lr, **base_kwargs)
        super().__init__(param_list, defaults=dict(lr=lr))
        self.s_every = scout_every
        self.radius = scout_radius
        self.steps = scout_steps
        self._step_id = 0
        self._params = param_list

    @staticmethod
    @torch.no_grad()
    def _flatten(tensors: List[torch.Tensor]):
        return torch.cat([t.reshape(-1) for t in tensors])

    @torch.no_grad()
    def _apply_delta(self, vec_flat: torch.Tensor, coef: float):
        offset = 0
        for p in self._params:
            n = p.numel()
            p.add_(vec_flat[offset:offset+n].view_as(p), alpha=coef)
            offset += n

    @staticmethod
    @torch.no_grad()
    def _rand_orthogonal(base: torch.Tensor):
        r = torch.randn_like(base)
        proj = (r @ base) / (base @ base + 1e-12)
        ortho = r - proj * base
        return ortho / (ortho.norm() + 1e-12)

    @torch.no_grad()
    def _track_direction(self, direction: torch.Tensor, closure, max_steps: int):
        best_loss = float('inf')
        best_step = 0

        for i in range(1, max_steps + 1):
            self._apply_delta(direction, self.radius)
            loss = closure()
            if loss < best_loss:
                best_loss = loss
                best_step = i

        self._apply_delta(direction, -self.radius * best_step)
        return best_loss, direction, best_step

    def step(self, closure=None):
        if closure is None:
            raise RuntimeError("ModifiedScoutOptimizer needs a closure that returns loss and does backward()")

        loss = closure()
        self._step_id += 1

        if self._step_id % self.s_every == 0:
            grad_flat = self._flatten([p.grad for p in self._params])
            grad_norm = grad_flat.norm() + 1e-12
            grad_dir = grad_flat / grad_norm
            ortho_dir = self._rand_orthogonal(grad_dir)

            directions = [
                grad_dir,
                ortho_dir,
                -ortho_dir
            ]

            best_loss = loss.item()
            best_dir = None
            best_scale = 0

            for d in directions:
                tracked_loss, d_dir, d_steps = self._track_direction(d, closure, self.steps)
                if tracked_loss < best_loss:
                    best_loss = tracked_loss
                    best_dir = d_dir
                    best_scale = d_steps

            if best_dir is not None:
                new_grad = best_dir * grad_norm
                offset = 0
                for p in self._params:
                    n = p.numel()
                    p.grad.copy_(new_grad[offset:offset+n].view_as(p))
                    offset += n

        self.base.step()
        return loss


# ------------------------------------------------------------------ #
#  3. Training / evaluation loops                                    #
# ------------------------------------------------------------------ #
@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    tot_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        out = model(x)
        tot_loss += criterion(out, y).item() * x.size(0)
        pred = out.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return tot_loss / total, correct / total


def train_one_epoch(model, loader, criterion, opt, device, log_every=100):
    model.train()
    running = 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)

        # Move x and y to new scope for each closure evaluation
        def closure():
            opt.base.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            if not loss.requires_grad:
                raise RuntimeError("Loss does not require grad. Check computation graph.")
            loss.backward()
            return loss

        loss = opt.step(closure)

        running += loss.item()
        if (i + 1) % log_every == 0:
            print(f"  batch {i+1}/{len(loader)}  loss {running/log_every:.3f}")
            running = 0.0

        # Debug: ensure gradient exists
        for name, param in model.named_parameters():
            if param.grad is None:
                print(f"WARNING: No gradient for {name}")
            else:
                print(f"Gradient norm for {name}: {param.grad.norm().item():.4e}")

def run_baseline_adam(epochs=6, batch=128, lr=3e-4, results=None):
    print("\nBaseline: Adam")
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])
    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)
    train_loader = DataLoader(train_set, batch_size=batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,   shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=1e-4)

    for ep in range(1, epochs+1):
        print(f"\nEpoch {ep}/{epochs}")
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}")
        if results is not None:
            results['adam_loss'].append(val_loss)
            results['adam_acc'].append(val_acc)

# ------------------------------------------------------------------ #
#  5. Main                                                           #
# ------------------------------------------------------------------ #

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--epochs', type=int, default=50)
    parser.add_argument('--batch',  type=int, default=128)
    parser.add_argument('--lr',     type=float, default=3e-4)
    parser.add_argument('--scout_every',  type=int, default=100)
    parser.add_argument('--scout_radius', type=float, default=5e-4)
    parser.add_argument('--gpu', action='store_true')
    args, _ = parser.parse_known_args()

    args.gpu = True  # Force GPU usage in Jupyter
    device = torch.device('cuda' if args.gpu and torch.cuda.is_available() else 'cpu')
    print('Using CUDA:', torch.cuda.is_available(), 'Device:', device)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])

    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, batch_size=args.batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,       shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    opt = ModifiedScoutOptimizer(
        model.parameters(), optim.Adam,
        lr=args.lr,
        scout_every=args.scout_every,
        scout_radius=args.scout_radius,
        scout_steps=50,
        betas=(0.9, 0.999),
        weight_decay=1e-4
    )

    results = {'scout_loss': [], 'scout_acc': [], 'adam_loss': [], 'adam_acc': []}

    for ep in range(1, args.epochs+1):
        print(f"\nEpoch {ep}/{args.epochs}")
        start = time.time()
        train_one_epoch(model, train_loader, criterion, opt, device)
        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
        results['scout_loss'].append(val_loss)
        results['scout_acc'].append(val_acc)

    torch.save(model.state_dict(), "scout_cnn.pth")
    print("Model saved to scout_cnn.pth")

    run_baseline_adam(epochs=args.epochs, batch=args.batch, lr=args.lr, results=results)

    print("\nFinal comparison table:")
    for i in range(args.epochs):
        print(f"Epoch {i+1:>2}:  Scout acc = {results['scout_acc'][i]*100:.2f}%  |  Adam acc = {results['adam_acc'][i]*100:.2f}%")

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(results['scout_loss'], label='Scout Loss')
    plt.plot(results['adam_loss'],  label='Adam Loss')
    plt.legend()
    plt.title("Validation Loss")

    plt.subplot(1, 2, 2)
    plt.plot(results['scout_acc'], label='Scout Acc')
    plt.plot(results['adam_acc'],  label='Adam Acc')
    plt.legend()
    plt.title("Validation Accuracy")
    plt.tight_layout()
    plt.show()

if __name__ == '__main__':
    if 'ipykernel' in sys.argv[0]:
        sys.argv = ['scout_opt_cifar10.py', '--gpu']
    main()
# Out:
# Using CUDA: True Device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch 1/50
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x000001F774670310>
# Traceback (most recent call last):
#   File "C:\Users\Machine-Learning\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\dataloader.py", line 1477, in __del__
#     self._shutdown_workers()
#   File "C:\Users\Machine-Learning\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\dataloader.py", line 1435, in _shutdown_workers
#     if self._persistent_workers or self._workers_status[worker_id]:
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# Gradient norm for conv1.weight: 2.7949e-02
# Gradient norm for conv1.bias: 4.2175e-03
# Gradient norm for conv2.weight: 1.2244e-01
# Gradient norm for conv2.bias: 8.3029e-03
# Gradient norm for conv3.weight: 1.9695e-01
# Gradient norm for conv3.bias: 1.7949e-02
# Gradient norm for fc1.weight: 4.4855e-01
# Gradient norm for fc1.bias: 3.7970e-02
# Gradient norm for fc2.weight: 1.1058e-01
# Gradient norm for fc2.bias: 1.0069e-01
# Gradient norm for conv1.weight: 2.6102e-02
# Gradient norm for conv1.bias: 4.6061e-03
# Gradient norm for conv2.weight: 1.3854e-01
# Gradient norm for conv2.bias: 1.0564e-02
# Gradient norm for conv3.weight: 2.2419e-01
# Gradient norm for conv3.bias: 2.3586e-02
# Gradient norm for fc1.weight: 5.0366e-01
# Gradient norm for fc1.bias: 4.7662e-02
# Gradient norm for fc2.weight: 1.9627e-01
# Gradient norm for fc2.bias: 1.1011e-01
# Gradient norm for conv1.weight: 3.5828e-02
# Gradient norm for conv1.bias: 4.3844e-03
# Gradient norm for conv2.weight: 1.5692e-01
# Gradient norm for conv2.bias: 9.5890e-03
# Gradient norm for conv3.weight: 2.2605e-01
# Gradient norm for conv3.bias: 2.1444e-02
# Gradient norm for fc1.weight: 4.9602e-01
# Gradient norm for fc1.bias: 4.0588e-02
# Gradient norm for fc2.weight: 2.5870e-01
# Gradient norm for fc2.bias: 1.0656e-01
# Gradient norm for conv1.weight: 2.8434e-02
# Gradient norm for conv1.bias: 4.9389e-03
# Gradient norm for conv2.weight: 1.7848e-01
# Gradient norm for conv2.bias: 1.3325e-02
# Gradient norm for conv3.weight: 2.4934e-01
# Gradient norm for conv3.bias: 2.4224e-02
# Gradient norm for fc1.weight: 5.6731e-01
# Gradient norm for fc1.bias: 4.3119e-02
# Gradient norm for fc2.weight: 3.3319e-01
# Gradient norm for fc2.bias: 1.1346e-01
# Gradient norm for conv1.weight: 3.2756e-02
# Gradient norm for conv1.bias: 6.3421e-03
# Gradient norm for conv2.weight: 1.5771e-01
# Gradient norm for conv2.bias: 1.2163e-02
# Gradient norm for conv3.weight: 2.2940e-01
# Gradient norm for conv3.bias: 2.3290e-02
# Gradient norm for fc1.weight: 5.1382e-01
# Gradient norm for fc1.bias: 4.0129e-02
# Gradient norm for fc2.weight: 3.1047e-01
# Gradient norm for fc2.bias: 1.0376e-01
# Gradient norm for conv1.weight: 6.1166e-02
# Gradient norm for conv1.bias: 9.0291e-03
# Gradient norm for conv2.weight: 2.1838e-01
# Gradient norm for conv2.bias: 1.1847e-02
# Gradient norm for conv3.weight: 2.2999e-01
# Gradient norm for conv3.bias: 1.8136e-02
# Gradient norm for fc1.weight: 3.9565e-01
# Gradient norm for fc1.bias: 2.8701e-02
# Gradient norm for fc2.weight: 2.4221e-01
# Gradient norm for fc2.bias: 6.9726e-02
# Gradient norm for conv1.weight: 8.0274e-02
# Gradient norm for conv1.bias: 1.0419e-02
# Gradient norm for conv2.weight: 2.5291e-01
# Gradient norm for conv2.bias: 1.2317e-02
# Gradient norm for conv3.weight: 2.5730e-01
# Gradient norm for conv3.bias: 1.8019e-02
# Gradient norm for fc1.weight: 4.8830e-01
# Gradient norm for fc1.bias: 3.2464e-02
# Gradient norm for fc2.weight: 3.2551e-01
# Gradient norm for fc2.bias: 8.1276e-02
# Gradient norm for conv1.weight: 6.0579e-02
# Gradient norm for conv1.bias: 1.0415e-02
# Gradient norm for conv2.weight: 1.9080e-01
# Gradient norm for conv2.bias: 1.4167e-02
# Gradient norm for conv3.weight: 2.3807e-01
# Gradient norm for conv3.bias: 2.5331e-02
# Gradient norm for fc1.weight: 4.7808e-01
# Gradient norm for fc1.bias: 4.1194e-02
# Gradient norm for fc2.weight: 3.6855e-01
# Gradient norm for fc2.bias: 1.1347e-01
# Gradient norm for conv1.weight: 7.7080e-02
# Gradient norm for conv1.bias: 1.4859e-02
# Gradient norm for conv2.weight: 2.5302e-01
# Gradient norm for conv2.bias: 1.7691e-02
# Gradient norm for conv3.weight: 2.7377e-01
# Gradient norm for conv3.bias: 2.1530e-02
# Gradient norm for fc1.weight: 4.7957e-01
# Gradient norm for fc1.bias: 2.6366e-02
# Gradient norm for fc2.weight: 3.7652e-01
# Gradient norm for fc2.bias: 8.0546e-02
# Gradient norm for conv1.weight: 1.0413e-01
# Gradient norm for conv1.bias: 2.7593e-02
# Gradient norm for conv2.weight: 4.0383e-01
# Gradient norm for conv2.bias: 3.4772e-02
# Gradient norm for conv3.weight: 4.1691e-01
# Gradient norm for conv3.bias: 3.9612e-02
# Gradient norm for fc1.weight: 7.0363e-01
# Gradient norm for fc1.bias: 4.6076e-02
# Gradient norm for fc2.weight: 5.1922e-01
# Gradient norm for fc2.bias: 1.2406e-01
# Gradient norm for conv1.weight: 1.1571e-01
# Gradient norm for conv1.bias: 1.8426e-02
# Gradient norm for conv2.weight: 3.2267e-01
# Gradient norm for conv2.bias: 2.5199e-02
# Gradient norm for conv3.weight: 3.7413e-01
# Gradient norm for conv3.bias: 3.3323e-02
# Gradient norm for fc1.weight: 8.7389e-01
# Gradient norm for fc1.bias: 4.7292e-02
# Gradient norm for fc2.weight: 6.5857e-01
# Gradient norm for fc2.bias: 1.1499e-01
# Gradient norm for conv1.weight: 8.9201e-02
# Gradient norm for conv1.bias: 2.6606e-02
# Gradient norm for conv2.weight: 3.5533e-01
# Gradient norm for conv2.bias: 3.0433e-02
# Gradient norm for conv3.weight: 4.6975e-01
# Gradient norm for conv3.bias: 3.8465e-02
# Gradient norm for fc1.weight: 1.1731e+00
# Gradient norm for fc1.bias: 5.3542e-02
# Gradient norm for fc2.weight: 1.0692e+00
# Gradient norm for fc2.bias: 1.3716e-01
# Gradient norm for conv1.weight: 8.1774e-02
# Gradient norm for conv1.bias: 1.5962e-02
# Gradient norm for conv2.weight: 2.2938e-01
# Gradient norm for conv2.bias: 1.6775e-02
# Gradient norm for conv3.weight: 3.1375e-01
# Gradient norm for conv3.bias: 2.1221e-02
# Gradient norm for fc1.weight: 8.7428e-01
# Gradient norm for fc1.bias: 3.2942e-02
# Gradient norm for fc2.weight: 7.9898e-01
# Gradient norm for fc2.bias: 7.9417e-02
# Gradient norm for conv1.weight: 7.9643e-02
# Gradient norm for conv1.bias: 1.4393e-02
# Gradient norm for conv2.weight: 2.2227e-01
# Gradient norm for conv2.bias: 1.4049e-02
# Gradient norm for conv3.weight: 3.0392e-01
# Gradient norm for conv3.bias: 1.9314e-02
# Gradient norm for fc1.weight: 8.6506e-01
# Gradient norm for fc1.bias: 3.2142e-02
# Gradient norm for fc2.weight: 7.8546e-01
# Gradient norm for fc2.bias: 8.6186e-02
# Gradient norm for conv1.weight: 2.2235e-01
# Gradient norm for conv1.bias: 3.6783e-02
# Gradient norm for conv2.weight: 6.7908e-01
# Gradient norm for conv2.bias: 3.9488e-02
# Gradient norm for conv3.weight: 7.8337e-01
# Gradient norm for conv3.bias: 4.3745e-02
# Gradient norm for fc1.weight: 1.6265e+00
# Gradient norm for fc1.bias: 4.9716e-02
# Gradient norm for fc2.weight: 1.5627e+00
# Gradient norm for fc2.bias: 1.2620e-01
# Gradient norm for conv1.weight: 2.0025e-01
# Gradient norm for conv1.bias: 2.8937e-02
# Gradient norm for conv2.weight: 4.4497e-01
# Gradient norm for conv2.bias: 2.7545e-02
# Gradient norm for conv3.weight: 5.1083e-01
# Gradient norm for conv3.bias: 3.2956e-02
# Gradient norm for fc1.weight: 1.6207e+00
# Gradient norm for fc1.bias: 5.6702e-02
# Gradient norm for fc2.weight: 1.6483e+00
# Gradient norm for fc2.bias: 1.4925e-01
# Gradient norm for conv1.weight: 2.8031e-01
# Gradient norm for conv1.bias: 8.2941e-02
# Gradient norm for conv2.weight: 8.3175e-01
# Gradient norm for conv2.bias: 7.7836e-02
# Gradient norm for conv3.weight: 7.0415e-01
# Gradient norm for conv3.bias: 5.6102e-02
# Gradient norm for fc1.weight: 1.3991e+00
# Gradient norm for fc1.bias: 5.2382e-02
# Gradient norm for fc2.weight: 1.4959e+00
# Gradient norm for fc2.bias: 1.3405e-01
# Gradient norm for conv1.weight: 2.4783e-01
# Gradient norm for conv1.bias: 6.2043e-02
# Gradient norm for conv2.weight: 6.9904e-01
# Gradient norm for conv2.bias: 5.9038e-02
# Gradient norm for conv3.weight: 5.9283e-01
# Gradient norm for conv3.bias: 4.2158e-02
# Gradient norm for fc1.weight: 1.2316e+00
# Gradient norm for fc1.bias: 4.0074e-02
# Gradient norm for fc2.weight: 1.2409e+00
# Gradient norm for fc2.bias: 1.0529e-01
# Gradient norm for conv1.weight: 2.8617e-01
# Gradient norm for conv1.bias: 3.6478e-02
# Gradient norm for conv2.weight: 5.5874e-01
# Gradient norm for conv2.bias: 2.4184e-02
# Gradient norm for conv3.weight: 4.8335e-01
# Gradient norm for conv3.bias: 2.2818e-02
# Gradient norm for fc1.weight: 1.2093e+00
# Gradient norm for fc1.bias: 3.4309e-02
# Gradient norm for fc2.weight: 1.3689e+00
# Gradient norm for fc2.bias: 9.5515e-02
# Gradient norm for conv1.weight: 1.3624e-01
# Gradient norm for conv1.bias: 2.2500e-02
# Gradient norm for conv2.weight: 3.2934e-01
# Gradient norm for conv2.bias: 2.1264e-02
# Gradient norm for conv3.weight: 4.2114e-01
# Gradient norm for conv3.bias: 2.9113e-02
# Gradient norm for fc1.weight: 1.2680e+00
# Gradient norm for fc1.bias: 4.4633e-02
# Gradient norm for fc2.weight: 1.4459e+00
# Gradient norm for fc2.bias: 1.2398e-01
# Gradient norm for conv1.weight: 4.4195e-01
# Gradient norm for conv1.bias: 1.0194e-01
# Gradient norm for conv2.weight: 1.1804e+00
# Gradient norm for conv2.bias: 9.0968e-02
# Gradient norm for conv3.weight: 9.9687e-01
# Gradient norm for conv3.bias: 5.9694e-02
# Gradient norm for fc1.weight: 1.8401e+00
# Gradient norm for fc1.bias: 5.8363e-02
# Gradient norm for fc2.weight: 2.2473e+00
# Gradient norm for fc2.bias: 1.6482e-01
# Gradient norm for conv1.weight: 1.2786e-01
# Gradient norm for conv1.bias: 2.4100e-02
# Gradient norm for conv2.weight: 3.0934e-01
# Gradient norm for conv2.bias: 1.8423e-02
# Gradient norm for conv3.weight: 3.7378e-01
# Gradient norm for conv3.bias: 1.9492e-02
# Gradient norm for fc1.weight: 1.1114e+00
# Gradient norm for fc1.bias: 3.3364e-02
# Gradient norm for fc2.weight: 1.2990e+00
# Gradient norm for fc2.bias: 8.7096e-02
# Gradient norm for conv1.weight: 1.6922e-01
# Gradient norm for conv1.bias: 1.6241e-02
# Gradient norm for conv2.weight: 2.8925e-01
# Gradient norm for conv2.bias: 1.3167e-02
# Gradient norm for conv3.weight: 3.1604e-01
# Gradient norm for conv3.bias: 1.6492e-02
# Gradient norm for fc1.weight: 9.8751e-01
# Gradient norm for fc1.bias: 3.0658e-02
# Gradient norm for fc2.weight: 1.2138e+00
# Gradient norm for fc2.bias: 8.2286e-02
# Gradient norm for conv1.weight: 3.7534e-01
# Gradient norm for conv1.bias: 3.9519e-02
# Gradient norm for conv2.weight: 6.9271e-01
# Gradient norm for conv2.bias: 3.6518e-02
# Gradient norm for conv3.weight: 5.5541e-01
# Gradient norm for conv3.bias: 3.3593e-02
# Gradient norm for fc1.weight: 1.2649e+00
# Gradient norm for fc1.bias: 4.2920e-02
# Gradient norm for fc2.weight: 1.5996e+00
# Gradient norm for fc2.bias: 1.1638e-01
# Gradient norm for conv1.weight: 2.3210e-01
# Gradient norm for conv1.bias: 3.3156e-02
# Gradient norm for conv2.weight: 4.3363e-01
# Gradient norm for conv2.bias: 2.1860e-02
# Gradient norm for conv3.weight: 4.9965e-01
# Gradient norm for conv3.bias: 3.1220e-02
# Gradient norm for fc1.weight: 1.4146e+00
# Gradient norm for fc1.bias: 4.9258e-02
# Gradient norm for fc2.weight: 1.7528e+00
# Gradient norm for fc2.bias: 1.3833e-01
# Gradient norm for conv1.weight: 4.7011e-01
# Gradient norm for conv1.bias: 1.4828e-01
# Gradient norm for conv2.weight: 1.1918e+00
# Gradient norm for conv2.bias: 1.0825e-01
# Gradient norm for conv3.weight: 7.7557e-01
# Gradient norm for conv3.bias: 5.6728e-02
# Gradient norm for fc1.weight: 1.1040e+00
# Gradient norm for fc1.bias: 3.9910e-02
# Gradient norm for fc2.weight: 1.3683e+00
# Gradient norm for fc2.bias: 9.9890e-02
# Gradient norm for conv1.weight: 4.0854e-01
# Gradient norm for conv1.bias: 7.2691e-02
# Gradient norm for conv2.weight: 8.4463e-01
# Gradient norm for conv2.bias: 6.5757e-02
# Gradient norm for conv3.weight: 6.9019e-01
# Gradient norm for conv3.bias: 4.9729e-02
# Gradient norm for fc1.weight: 1.3227e+00
# Gradient norm for fc1.bias: 4.3729e-02
# Gradient norm for fc2.weight: 1.6812e+00
# Gradient norm for fc2.bias: 1.1235e-01
# Gradient norm for conv1.weight: 3.0258e-01
# Gradient norm for conv1.bias: 2.4969e-02
# Gradient norm for conv2.weight: 4.2428e-01
# Gradient norm for conv2.bias: 2.4229e-02
# Gradient norm for conv3.weight: 4.1129e-01
# Gradient norm for conv3.bias: 3.2925e-02
# Gradient norm for fc1.weight: 1.2141e+00
# Gradient norm for fc1.bias: 4.8745e-02
# Gradient norm for fc2.weight: 1.6200e+00
# Gradient norm for fc2.bias: 1.3344e-01
# Gradient norm for conv1.weight: 6.4683e-01
# Gradient norm for conv1.bias: 1.4934e-01
# Gradient norm for conv2.weight: 1.3239e+00
# Gradient norm for conv2.bias: 1.1539e-01
# Gradient norm for conv3.weight: 7.5874e-01
# Gradient norm for conv3.bias: 5.7241e-02
# Gradient norm for fc1.weight: 1.2268e+00
# Gradient norm for fc1.bias: 4.2426e-02
# Gradient norm for fc2.weight: 1.7282e+00
# Gradient norm for fc2.bias: 1.1949e-01
# Gradient norm for conv1.weight: 3.0984e-01
# Gradient norm for conv1.bias: 6.6979e-02
# Gradient norm for conv2.weight: 7.1973e-01
# Gradient norm for conv2.bias: 5.0304e-02
# Gradient norm for conv3.weight: 5.0280e-01
# Gradient norm for conv3.bias: 2.8149e-02
# Gradient norm for fc1.weight: 1.0155e+00
# Gradient norm for fc1.bias: 3.4308e-02
# Gradient norm for fc2.weight: 1.3256e+00
# Gradient norm for fc2.bias: 1.0113e-01
# Gradient norm for conv1.weight: 2.5147e-01
# Gradient norm for conv1.bias: 3.2112e-02
# Gradient norm for conv2.weight: 5.7233e-01
# Gradient norm for conv2.bias: 3.0319e-02
# Gradient norm for conv3.weight: 5.1313e-01
# Gradient norm for conv3.bias: 2.7050e-02
# Gradient norm for fc1.weight: 1.0162e+00
# Gradient norm for fc1.bias: 3.0268e-02
# Gradient norm for fc2.weight: 1.3617e+00
# Gradient norm for fc2.bias: 7.9865e-02
# Gradient norm for conv1.weight: 4.9994e-01
# Gradient norm for conv1.bias: 1.5791e-01
# Gradient norm for conv2.weight: 1.2433e+00
# Gradient norm for conv2.bias: 1.1262e-01
# Gradient norm for conv3.weight: 8.1723e-01
# Gradient norm for conv3.bias: 5.5446e-02
# Gradient norm for fc1.weight: 1.1659e+00
# Gradient norm for fc1.bias: 3.9923e-02
# Gradient norm for fc2.weight: 1.5213e+00
# Gradient norm for fc2.bias: 1.0546e-01
# Gradient norm for conv1.weight: 2.6339e-01
# Gradient norm for conv1.bias: 5.9079e-02
# Gradient norm for conv2.weight: 6.7373e-01
# Gradient norm for conv2.bias: 4.4016e-02
# Gradient norm for conv3.weight: 6.4454e-01
# Gradient norm for conv3.bias: 3.3779e-02
# Gradient norm for fc1.weight: 1.3332e+00
# Gradient norm for fc1.bias: 3.9451e-02
# Gradient norm for fc2.weight: 1.6987e+00
# Gradient norm for fc2.bias: 1.0914e-01
# Gradient norm for conv1.weight: 1.8709e-01
# Gradient norm for conv1.bias: 2.6900e-02
# Gradient norm for conv2.weight: 3.9137e-01
# Gradient norm for conv2.bias: 3.3176e-02
# Gradient norm for conv3.weight: 4.2042e-01
# Gradient norm for conv3.bias: 3.1376e-02
# Gradient norm for fc1.weight: 1.0787e+00
# Gradient norm for fc1.bias: 3.7939e-02
# Gradient norm for fc2.weight: 1.4872e+00
# Gradient norm for fc2.bias: 1.0076e-01
# Gradient norm for conv1.weight: 5.9558e-01
# Gradient norm for conv1.bias: 1.2733e-01
# Gradient norm for conv2.weight: 1.0325e+00
# Gradient norm for conv2.bias: 1.0192e-01
# Gradient norm for conv3.weight: 6.5430e-01
# Gradient norm for conv3.bias: 5.7614e-02
# Gradient norm for fc1.weight: 1.1774e+00
# Gradient norm for fc1.bias: 4.0035e-02
# Gradient norm for fc2.weight: 1.5640e+00
# Gradient norm for fc2.bias: 9.5676e-02
# Gradient norm for conv1.weight: 3.9717e-01
# Gradient norm for conv1.bias: 1.0062e-01
# Gradient norm for conv2.weight: 7.5198e-01
# Gradient norm for conv2.bias: 7.5077e-02
# Gradient norm for conv3.weight: 5.2581e-01
# Gradient norm for conv3.bias: 4.0596e-02
# Gradient norm for fc1.weight: 1.1677e+00
# Gradient norm for fc1.bias: 3.5511e-02
# Gradient norm for fc2.weight: 1.7426e+00
# Gradient norm for fc2.bias: 9.3201e-02
# Gradient norm for conv1.weight: 2.5050e-01
# Gradient norm for conv1.bias: 4.6159e-02
# Gradient norm for conv2.weight: 5.8796e-01
# Gradient norm for conv2.bias: 5.1189e-02
# Gradient norm for conv3.weight: 6.1625e-01
# Gradient norm for conv3.bias: 4.4274e-02
# Gradient norm for fc1.weight: 1.4318e+00
# Gradient norm for fc1.bias: 4.5578e-02
# Gradient norm for fc2.weight: 1.9826e+00
# Gradient norm for fc2.bias: 1.1848e-01
# Gradient norm for conv1.weight: 7.0738e-01
# Gradient norm for conv1.bias: 2.2352e-01
# Gradient norm for conv2.weight: 1.9454e+00
# Gradient norm for conv2.bias: 1.6070e-01
# Gradient norm for conv3.weight: 1.3455e+00
# Gradient norm for conv3.bias: 8.3656e-02
# Gradient norm for fc1.weight: 1.5735e+00
# Gradient norm for fc1.bias: 4.8024e-02
# Gradient norm for fc2.weight: 2.0907e+00
# Gradient norm for fc2.bias: 1.2450e-01
# Gradient norm for conv1.weight: 4.3160e-01
# Gradient norm for conv1.bias: 8.2132e-02
# Gradient norm for conv2.weight: 9.7709e-01
# Gradient norm for conv2.bias: 5.8708e-02
# Gradient norm for conv3.weight: 7.2658e-01
# Gradient norm for conv3.bias: 3.5666e-02
# Gradient norm for fc1.weight: 1.3206e+00
# Gradient norm for fc1.bias: 4.0226e-02
# Gradient norm for fc2.weight: 1.7430e+00
# Gradient norm for fc2.bias: 1.1089e-01
# Gradient norm for conv1.weight: 2.8926e-01
# Gradient norm for conv1.bias: 8.6326e-02
# Gradient norm for conv2.weight: 7.1675e-01
# Gradient norm for conv2.bias: 5.7463e-02
# Gradient norm for conv3.weight: 5.5025e-01
# Gradient norm for conv3.bias: 3.2445e-02
# Gradient norm for fc1.weight: 1.0759e+00
# Gradient norm for fc1.bias: 2.9968e-02
# Gradient norm for fc2.weight: 1.4394e+00
# Gradient norm for fc2.bias: 7.6774e-02
# Gradient norm for conv1.weight: 5.1513e-01
# Gradient norm for conv1.bias: 1.9676e-01
# Gradient norm for conv2.weight: 1.4510e+00
# Gradient norm for conv2.bias: 1.3365e-01
# Gradient norm for conv3.weight: 9.9183e-01
# Gradient norm for conv3.bias: 6.6652e-02
# Gradient norm for fc1.weight: 1.5346e+00
# Gradient norm for fc1.bias: 4.2184e-02
# Gradient norm for fc2.weight: 2.1800e+00
# Gradient norm for fc2.bias: 1.0884e-01
# Gradient norm for conv1.weight: 4.8301e-01
# Gradient norm for conv1.bias: 1.0999e-01
# Gradient norm for conv2.weight: 1.0502e+00
# Gradient norm for conv2.bias: 7.4373e-02
# Gradient norm for conv3.weight: 7.7817e-01
# Gradient norm for conv3.bias: 4.3241e-02
# Gradient norm for fc1.weight: 1.3346e+00
# Gradient norm for fc1.bias: 3.3824e-02
# Gradient norm for fc2.weight: 2.1096e+00
# Gradient norm for fc2.bias: 8.7389e-02
# Gradient norm for conv1.weight: 3.2934e-01
# Gradient norm for conv1.bias: 8.5229e-02
# Gradient norm for conv2.weight: 7.6524e-01
# Gradient norm for conv2.bias: 5.5975e-02
# Gradient norm for conv3.weight: 5.7924e-01
# Gradient norm for conv3.bias: 3.2815e-02
# Gradient norm for fc1.weight: 1.2502e+00
# Gradient norm for fc1.bias: 3.0983e-02
# Gradient norm for fc2.weight: 1.8311e+00
# Gradient norm for fc2.bias: 8.6680e-02
# Gradient norm for conv1.weight: 3.7616e-01
# Gradient norm for conv1.bias: 6.5909e-02
# Gradient norm for conv2.weight: 8.0214e-01
# Gradient norm for conv2.bias: 6.0565e-02
# Gradient norm for conv3.weight: 7.2673e-01
# Gradient norm for conv3.bias: 4.7654e-02
# Gradient norm for fc1.weight: 1.5399e+00
# Gradient norm for fc1.bias: 4.5796e-02
# Gradient norm for fc2.weight: 2.3492e+00
# Gradient norm for fc2.bias: 1.2494e-01
# Gradient norm for conv1.weight: 5.4593e-01
# Gradient norm for conv1.bias: 9.8413e-02
# Gradient norm for conv2.weight: 1.1187e+00
# Gradient norm for conv2.bias: 8.7974e-02
# Gradient norm for conv3.weight: 8.2762e-01
# Gradient norm for conv3.bias: 6.1888e-02
# Gradient norm for fc1.weight: 1.7796e+00
# Gradient norm for fc1.bias: 5.3311e-02
# Gradient norm for fc2.weight: 2.5254e+00
# Gradient norm for fc2.bias: 1.4206e-01
# Gradient norm for conv1.weight: 5.0321e-01
# Gradient norm for conv1.bias: 1.1119e-01
# Gradient norm for conv2.weight: 1.1926e+00
# Gradient norm for conv2.bias: 9.0937e-02
# Gradient norm for conv3.weight: 8.9581e-01
# Gradient norm for conv3.bias: 5.7362e-02
# Gradient norm for fc1.weight: 1.4978e+00
# Gradient norm for fc1.bias: 4.1041e-02
# Gradient norm for fc2.weight: 2.1123e+00
# Gradient norm for fc2.bias: 1.0429e-01
# Gradient norm for conv1.weight: 2.4407e-01
# Gradient norm for conv1.bias: 4.4491e-02
# Gradient norm for conv2.weight: 4.4645e-01
# Gradient norm for conv2.bias: 3.7674e-02
# Gradient norm for conv3.weight: 4.6524e-01
# Gradient norm for conv3.bias: 3.2848e-02
# Gradient norm for fc1.weight: 1.2236e+00
# Gradient norm for fc1.bias: 3.5714e-02
# Gradient norm for fc2.weight: 1.9172e+00
# Gradient norm for fc2.bias: 1.0510e-01
# Gradient norm for conv1.weight: 5.9169e-01
# Gradient norm for conv1.bias: 2.1772e-01
# Gradient norm for conv2.weight: 1.6177e+00
# Gradient norm for conv2.bias: 1.5200e-01
# Gradient norm for conv3.weight: 1.1005e+00
# Gradient norm for conv3.bias: 7.7036e-02
# Gradient norm for fc1.weight: 1.6072e+00
# Gradient norm for fc1.bias: 4.8679e-02
# Gradient norm for fc2.weight: 2.3866e+00
# Gradient norm for fc2.bias: 1.2577e-01
# Gradient norm for conv1.weight: 4.9541e-01
# Gradient norm for conv1.bias: 5.6089e-02
# Gradient norm for conv2.weight: 8.7934e-01
# Gradient norm for conv2.bias: 4.0449e-02
# Gradient norm for conv3.weight: 7.0623e-01
# Gradient norm for conv3.bias: 2.8872e-02
# Gradient norm for fc1.weight: 1.2496e+00
# Gradient norm for fc1.bias: 2.9908e-02
# Gradient norm for fc2.weight: 1.8363e+00
# Gradient norm for fc2.bias: 8.1783e-02
# Gradient norm for conv1.weight: 3.2186e-01
# Gradient norm for conv1.bias: 7.9561e-02
# Gradient norm for conv2.weight: 7.3155e-01
# Gradient norm for conv2.bias: 5.7410e-02
# Gradient norm for conv3.weight: 7.5515e-01
# Gradient norm for conv3.bias: 4.0113e-02
# Gradient norm for fc1.weight: 1.4405e+00
# Gradient norm for fc1.bias: 3.5674e-02
# Gradient norm for fc2.weight: 2.1662e+00
# Gradient norm for fc2.bias: 8.8618e-02
# Gradient norm for conv1.weight: 3.2058e-01
# Gradient norm for conv1.bias: 3.3080e-02
# Gradient norm for conv2.weight: 5.8571e-01
# Gradient norm for conv2.bias: 2.2523e-02
# Gradient norm for conv3.weight: 5.6452e-01
# Gradient norm for conv3.bias: 2.8047e-02
# Gradient norm for fc1.weight: 1.2900e+00
# Gradient norm for fc1.bias: 3.7761e-02
# Gradient norm for fc2.weight: 1.8788e+00
# Gradient norm for fc2.bias: 1.0060e-01
# Gradient norm for conv1.weight: 6.9383e-01
# Gradient norm for conv1.bias: 1.7004e-01
# Gradient norm for conv2.weight: 1.6067e+00
# Gradient norm for conv2.bias: 1.2155e-01
# Gradient norm for conv3.weight: 1.1978e+00
# Gradient norm for conv3.bias: 7.6382e-02
# Gradient norm for fc1.weight: 1.9464e+00
# Gradient norm for fc1.bias: 6.1400e-02
# Gradient norm for fc2.weight: 2.7085e+00
# Gradient norm for fc2.bias: 1.4667e-01
# Gradient norm for conv1.weight: 1.7418e-01
# Gradient norm for conv1.bias: 7.6829e-02
# Gradient norm for conv2.weight: 4.8863e-01
# Gradient norm for conv2.bias: 5.7695e-02
# Gradient norm for conv3.weight: 5.2194e-01
# Gradient norm for conv3.bias: 3.9661e-02
# Gradient norm for fc1.weight: 1.3950e+00
# Gradient norm for fc1.bias: 4.1447e-02
# Gradient norm for fc2.weight: 2.2729e+00
# Gradient norm for fc2.bias: 1.1855e-01
# Gradient norm for conv1.weight: 4.8152e-01
# Gradient norm for conv1.bias: 1.4862e-01
# Gradient norm for conv2.weight: 1.1709e+00
# Gradient norm for conv2.bias: 9.7554e-02
# Gradient norm for conv3.weight: 8.6510e-01
# Gradient norm for conv3.bias: 5.4797e-02
# Gradient norm for fc1.weight: 1.5771e+00
# Gradient norm for fc1.bias: 4.6791e-02
# Gradient norm for fc2.weight: 2.3426e+00
# Gradient norm for fc2.bias: 1.1577e-01
# Gradient norm for conv1.weight: 5.4028e-01
# Gradient norm for conv1.bias: 9.7564e-02
# Gradient norm for conv2.weight: 1.2419e+00
# Gradient norm for conv2.bias: 6.5258e-02
# Gradient norm for conv3.weight: 8.7907e-01
# Gradient norm for conv3.bias: 4.1905e-02
# Gradient norm for fc1.weight: 1.3961e+00
# Gradient norm for fc1.bias: 4.3338e-02
# Gradient norm for fc2.weight: 1.9392e+00
# Gradient norm for fc2.bias: 1.0681e-01
# Gradient norm for conv1.weight: 4.0005e-01
# Gradient norm for conv1.bias: 3.5552e-02
# Gradient norm for conv2.weight: 7.2266e-01
# Gradient norm for conv2.bias: 2.6455e-02
# Gradient norm for conv3.weight: 6.3697e-01
# Gradient norm for conv3.bias: 2.6763e-02
# Gradient norm for fc1.weight: 1.2441e+00
# Gradient norm for fc1.bias: 3.3514e-02
# Gradient norm for fc2.weight: 1.7522e+00
# Gradient norm for fc2.bias: 8.7972e-02
# Gradient norm for conv1.weight: 4.4974e-01
# Gradient norm for conv1.bias: 1.0108e-01
# Gradient norm for conv2.weight: 8.9909e-01
# Gradient norm for conv2.bias: 7.4755e-02
# Gradient norm for conv3.weight: 7.7373e-01
# Gradient norm for conv3.bias: 5.0672e-02
# Gradient norm for fc1.weight: 1.8874e+00
# Gradient norm for fc1.bias: 5.4010e-02
# Gradient norm for fc2.weight: 3.0502e+00
# Gradient norm for fc2.bias: 1.4606e-01
# Gradient norm for conv1.weight: 7.5699e-01
# Gradient norm for conv1.bias: 2.6309e-01
# Gradient norm for conv2.weight: 1.9882e+00
# Gradient norm for conv2.bias: 1.8461e-01
# Gradient norm for conv3.weight: 1.1908e+00
# Gradient norm for conv3.bias: 8.8998e-02
# Gradient norm for fc1.weight: 1.4002e+00
# Gradient norm for fc1.bias: 4.2043e-02
# Gradient norm for fc2.weight: 2.0867e+00
# Gradient norm for fc2.bias: 1.0600e-01
# Gradient norm for conv1.weight: 2.3017e-01
# Gradient norm for conv1.bias: 5.8247e-02
# Gradient norm for conv2.weight: 5.2122e-01
# Gradient norm for conv2.bias: 5.4824e-02
# Gradient norm for conv3.weight: 4.7949e-01
# Gradient norm for conv3.bias: 4.1208e-02
# Gradient norm for fc1.weight: 9.3206e-01
# Gradient norm for fc1.bias: 3.0857e-02
# Gradient norm for fc2.weight: 1.4380e+00
# Gradient norm for fc2.bias: 8.3140e-02
# Gradient norm for conv1.weight: 4.6865e-01
# Gradient norm for conv1.bias: 1.6223e-01
# Gradient norm for conv2.weight: 1.2523e+00
# Gradient norm for conv2.bias: 1.0787e-01
# Gradient norm for conv3.weight: 9.1633e-01
# Gradient norm for conv3.bias: 6.0871e-02
# Gradient norm for fc1.weight: 1.9125e+00
# Gradient norm for fc1.bias: 6.3583e-02
# Gradient norm for fc2.weight: 3.0108e+00
# Gradient norm for fc2.bias: 1.6590e-01
# Gradient norm for conv1.weight: 6.6309e-01
# Gradient norm for conv1.bias: 1.2999e-01
# Gradient norm for conv2.weight: 1.3743e+00
# Gradient norm for conv2.bias: 8.1398e-02
# Gradient norm for conv3.weight: 8.3200e-01
# Gradient norm for conv3.bias: 4.2883e-02
# Gradient norm for fc1.weight: 1.1427e+00
# Gradient norm for fc1.bias: 3.0517e-02
# Gradient norm for fc2.weight: 1.7039e+00
# Gradient norm for fc2.bias: 7.6930e-02
# Gradient norm for conv1.weight: 3.4687e-01
# Gradient norm for conv1.bias: 1.5105e-01
# Gradient norm for conv2.weight: 1.0549e+00
# Gradient norm for conv2.bias: 1.0836e-01
# Gradient norm for conv3.weight: 8.4072e-01
# Gradient norm for conv3.bias: 6.2938e-02
# Gradient norm for fc1.weight: 1.2787e+00
# Gradient norm for fc1.bias: 4.4651e-02
# Gradient norm for fc2.weight: 2.0550e+00
# Gradient norm for fc2.bias: 1.1857e-01
# Gradient norm for conv1.weight: 4.4241e-01
# Gradient norm for conv1.bias: 1.1299e-01
# Gradient norm for conv2.weight: 8.1187e-01
# Gradient norm for conv2.bias: 7.4240e-02
# Gradient norm for conv3.weight: 8.0996e-01
# Gradient norm for conv3.bias: 5.1176e-02
# Gradient norm for fc1.weight: 1.7908e+00
# Gradient norm for fc1.bias: 5.6973e-02
# Gradient norm for fc2.weight: 3.0451e+00
# Gradient norm for fc2.bias: 1.5575e-01
# Gradient norm for conv1.weight: 5.5005e-01
# Gradient norm for conv1.bias: 6.1194e-02
# Gradient norm for conv2.weight: 8.3989e-01
# Gradient norm for conv2.bias: 4.6149e-02
# Gradient norm for conv3.weight: 5.6608e-01
# Gradient norm for conv3.bias: 3.1594e-02
# Gradient norm for fc1.weight: 1.3973e+00
# Gradient norm for fc1.bias: 4.5339e-02
# Gradient norm for fc2.weight: 2.3921e+00
# Gradient norm for fc2.bias: 1.3050e-01
# Gradient norm for conv1.weight: 4.8835e-01
# Gradient norm for conv1.bias: 9.9221e-02
# Gradient norm for conv2.weight: 1.0182e+00
# Gradient norm for conv2.bias: 6.4393e-02
# Gradient norm for conv3.weight: 6.9794e-01
# Gradient norm for conv3.bias: 3.7650e-02
# Gradient norm for fc1.weight: 1.2899e+00
# Gradient norm for fc1.bias: 4.1367e-02
# Gradient norm for fc2.weight: 2.1214e+00
# Gradient norm for fc2.bias: 1.1326e-01
# Gradient norm for conv1.weight: 5.1459e-01
# Gradient norm for conv1.bias: 1.3388e-01
# Gradient norm for conv2.weight: 1.0700e+00
# Gradient norm for conv2.bias: 8.1828e-02
# Gradient norm for conv3.weight: 6.3291e-01
# Gradient norm for conv3.bias: 3.6379e-02
# Gradient norm for fc1.weight: 8.5073e-01
# Gradient norm for fc1.bias: 2.4926e-02
# Gradient norm for fc2.weight: 1.1559e+00
# Gradient norm for fc2.bias: 5.7093e-02
# Gradient norm for conv1.weight: 3.1421e-01
# Gradient norm for conv1.bias: 9.2630e-02
# Gradient norm for conv2.weight: 6.3204e-01
# Gradient norm for conv2.bias: 7.3625e-02
# Gradient norm for conv3.weight: 5.2734e-01
# Gradient norm for conv3.bias: 4.7344e-02
# Gradient norm for fc1.weight: 1.0641e+00
# Gradient norm for fc1.bias: 3.5374e-02
# Gradient norm for fc2.weight: 1.7858e+00
# Gradient norm for fc2.bias: 9.2774e-02
# Gradient norm for conv1.weight: 2.7538e-01
# Gradient norm for conv1.bias: 8.6276e-02
# Gradient norm for conv2.weight: 7.3834e-01
# Gradient norm for conv2.bias: 8.4055e-02
# Gradient norm for conv3.weight: 6.7744e-01
# Gradient norm for conv3.bias: 5.3492e-02
# Gradient norm for fc1.weight: 1.2553e+00
# Gradient norm for fc1.bias: 3.9037e-02
# Gradient norm for fc2.weight: 1.9973e+00
# Gradient norm for fc2.bias: 1.0117e-01
# Gradient norm for conv1.weight: 2.5991e-01
# Gradient norm for conv1.bias: 7.6657e-02
# Gradient norm for conv2.weight: 4.9414e-01
# Gradient norm for conv2.bias: 5.9130e-02
# Gradient norm for conv3.weight: 4.7081e-01
# Gradient norm for conv3.bias: 3.2361e-02
# Gradient norm for fc1.weight: 1.6815e+00
# Gradient norm for fc1.bias: 4.3920e-02
# Gradient norm for fc2.weight: 3.1506e+00
# Gradient norm for fc2.bias: 1.2778e-01
# Gradient norm for conv1.weight: 7.1680e-01
# Gradient norm for conv1.bias: 1.0774e-01
# Gradient norm for conv2.weight: 1.3476e+00
# Gradient norm for conv2.bias: 8.3659e-02
# Gradient norm for conv3.weight: 9.5804e-01
# Gradient norm for conv3.bias: 5.6111e-02
# Gradient norm for fc1.weight: 1.5983e+00
# Gradient norm for fc1.bias: 4.5364e-02
# Gradient norm for fc2.weight: 2.6010e+00
# Gradient norm for fc2.bias: 1.1811e-01
# Gradient norm for conv1.weight: 3.4463e-01
# Gradient norm for conv1.bias: 6.6706e-02
# Gradient norm for conv2.weight: 6.9625e-01
# Gradient norm for conv2.bias: 5.0770e-02
# Gradient norm for conv3.weight: 5.4849e-01
# Gradient norm for conv3.bias: 2.8316e-02
# Gradient norm for fc1.weight: 9.0625e-01
# Gradient norm for fc1.bias: 2.4178e-02
# Gradient norm for fc2.weight: 1.4057e+00
# Gradient norm for fc2.bias: 6.4162e-02
# Gradient norm for conv1.weight: 7.2401e-01
# Gradient norm for conv1.bias: 1.6587e-01
# Gradient norm for conv2.weight: 1.5113e+00
# Gradient norm for conv2.bias: 1.0284e-01
# Gradient norm for conv3.weight: 1.0729e+00
# Gradient norm for conv3.bias: 5.5509e-02
# Gradient norm for fc1.weight: 1.7739e+00
# Gradient norm for fc1.bias: 4.1158e-02
# Gradient norm for fc2.weight: 3.0017e+00
# Gradient norm for fc2.bias: 1.0730e-01
# Gradient norm for conv1.weight: 7.9732e-01
# Gradient norm for conv1.bias: 2.9938e-01
# Gradient norm for conv2.weight: 1.9742e+00
# Gradient norm for conv2.bias: 1.7701e-01
# Gradient norm for conv3.weight: 1.2052e+00
# Gradient norm for conv3.bias: 7.5156e-02
# Gradient norm for fc1.weight: 1.9450e+00
# Gradient norm for fc1.bias: 4.9571e-02
# Gradient norm for fc2.weight: 3.0073e+00
# Gradient norm for fc2.bias: 1.1614e-01
# Gradient norm for conv1.weight: 7.3786e-01
# Gradient norm for conv1.bias: 2.0566e-01
# Gradient norm for conv2.weight: 1.9311e+00
# Gradient norm for conv2.bias: 1.3699e-01
# Gradient norm for conv3.weight: 1.2053e+00
# Gradient norm for conv3.bias: 6.1979e-02
# Gradient norm for fc1.weight: 1.4546e+00
# Gradient norm for fc1.bias: 3.5297e-02
# Gradient norm for fc2.weight: 2.2387e+00
# Gradient norm for fc2.bias: 8.6235e-02
# Gradient norm for conv1.weight: 4.9834e-01
# Gradient norm for conv1.bias: 5.3828e-02
# Gradient norm for conv2.weight: 7.4040e-01
# Gradient norm for conv2.bias: 5.3125e-02
# Gradient norm for conv3.weight: 6.2061e-01
# Gradient norm for conv3.bias: 4.1707e-02
# Gradient norm for fc1.weight: 1.1509e+00
# Gradient norm for fc1.bias: 2.9936e-02
# Gradient norm for fc2.weight: 1.8227e+00
# Gradient norm for fc2.bias: 7.7671e-02
# Gradient norm for conv1.weight: 9.4648e-01
# Gradient norm for conv1.bias: 8.4333e-02
# Gradient norm for conv2.weight: 1.4488e+00
# Gradient norm for conv2.bias: 6.7905e-02
# Gradient norm for conv3.weight: 8.5717e-01
# Gradient norm for conv3.bias: 5.1645e-02
# Gradient norm for fc1.weight: 1.5415e+00
# Gradient norm for fc1.bias: 4.0446e-02
# Gradient norm for fc2.weight: 2.5176e+00
# Gradient norm for fc2.bias: 9.6409e-02
# Gradient norm for conv1.weight: 9.4961e-01
# Gradient norm for conv1.bias: 1.2334e-01
# Gradient norm for conv2.weight: 1.4571e+00
# Gradient norm for conv2.bias: 9.1286e-02
# Gradient norm for conv3.weight: 9.5093e-01
# Gradient norm for conv3.bias: 5.7289e-02
# Gradient norm for fc1.weight: 1.5599e+00
# Gradient norm for fc1.bias: 4.1342e-02
# Gradient norm for fc2.weight: 2.6128e+00
# Gradient norm for fc2.bias: 1.0209e-01
# Gradient norm for conv1.weight: 6.9275e-01
# Gradient norm for conv1.bias: 8.1799e-02
# Gradient norm for conv2.weight: 1.2796e+00
# Gradient norm for conv2.bias: 6.3980e-02
# Gradient norm for conv3.weight: 9.8328e-01
# Gradient norm for conv3.bias: 4.2369e-02
# Gradient norm for fc1.weight: 1.2197e+00
# Gradient norm for fc1.bias: 2.9930e-02
# Gradient norm for fc2.weight: 1.9340e+00
# Gradient norm for fc2.bias: 7.5212e-02
# Gradient norm for conv1.weight: 4.8646e-01
# Gradient norm for conv1.bias: 1.1046e-01
# Gradient norm for conv2.weight: 8.5841e-01
# Gradient norm for conv2.bias: 5.5327e-02
# Gradient norm for conv3.weight: 8.3495e-01
# Gradient norm for conv3.bias: 4.0203e-02
# Gradient norm for fc1.weight: 1.8796e+00
# Gradient norm for fc1.bias: 4.9928e-02
# Gradient norm for fc2.weight: 3.2501e+00
# Gradient norm for fc2.bias: 1.3183e-01
# Gradient norm for conv1.weight: 7.6506e-01
# Gradient norm for conv1.bias: 1.6620e-01
# Gradient norm for conv2.weight: 1.5868e+00
# Gradient norm for conv2.bias: 1.1578e-01
# Gradient norm for conv3.weight: 1.0159e+00
# Gradient norm for conv3.bias: 5.7606e-02
# Gradient norm for fc1.weight: 1.3532e+00
# Gradient norm for fc1.bias: 3.4240e-02
# Gradient norm for fc2.weight: 2.2445e+00
# Gradient norm for fc2.bias: 8.9955e-02
# Gradient norm for conv1.weight: 7.2698e-01
# Gradient norm for conv1.bias: 1.7911e-01
# Gradient norm for conv2.weight: 1.2785e+00
# Gradient norm for conv2.bias: 1.2028e-01
# Gradient norm for conv3.weight: 1.0280e+00
# Gradient norm for conv3.bias: 6.5495e-02
# Gradient norm for fc1.weight: 1.7456e+00
# Gradient norm for fc1.bias: 4.4312e-02
# Gradient norm for fc2.weight: 2.7844e+00
# Gradient norm for fc2.bias: 1.0719e-01
# Gradient norm for conv1.weight: 6.4627e-01
# Gradient norm for conv1.bias: 7.0743e-02
# Gradient norm for conv2.weight: 9.4792e-01
# Gradient norm for conv2.bias: 6.5862e-02
# Gradient norm for conv3.weight: 8.2742e-01
# Gradient norm for conv3.bias: 5.1590e-02
# Gradient norm for fc1.weight: 1.6390e+00
# Gradient norm for fc1.bias: 4.3660e-02
# Gradient norm for fc2.weight: 2.9078e+00
# Gradient norm for fc2.bias: 1.1553e-01
# Gradient norm for conv1.weight: 5.9220e-01
# Gradient norm for conv1.bias: 1.3142e-01
# Gradient norm for conv2.weight: 1.4732e+00
# Gradient norm for conv2.bias: 1.0047e-01
# Gradient norm for conv3.weight: 1.1629e+00
# Gradient norm for conv3.bias: 6.6057e-02
# Gradient norm for fc1.weight: 2.0694e+00
# Gradient norm for fc1.bias: 4.9885e-02
# Gradient norm for fc2.weight: 3.5750e+00
# Gradient norm for fc2.bias: 1.3072e-01
# Gradient norm for conv1.weight: 4.5599e-01
# Gradient norm for conv1.bias: 1.0242e-01
# Gradient norm for conv2.weight: 8.7622e-01
# Gradient norm for conv2.bias: 8.8048e-02
# Gradient norm for conv3.weight: 7.8461e-01
# Gradient norm for conv3.bias: 6.0900e-02
# Gradient norm for fc1.weight: 1.6719e+00
# Gradient norm for fc1.bias: 5.0955e-02
# Gradient norm for fc2.weight: 2.9055e+00
# Gradient norm for fc2.bias: 1.3274e-01
# Gradient norm for conv1.weight: 5.5743e-01
# Gradient norm for conv1.bias: 1.2968e-01
# Gradient norm for conv2.weight: 1.6266e+00
# Gradient norm for conv2.bias: 1.3014e-01
# Gradient norm for conv3.weight: 1.3568e+00
# Gradient norm for conv3.bias: 8.2227e-02
# Gradient norm for fc1.weight: 1.6831e+00
# Gradient norm for fc1.bias: 4.7111e-02
# Gradient norm for fc2.weight: 2.7226e+00
# Gradient norm for fc2.bias: 1.1704e-01
# Gradient norm for conv1.weight: 3.7668e-01
# Gradient norm for conv1.bias: 5.1309e-02
# Gradient norm for conv2.weight: 7.2138e-01
# Gradient norm for conv2.bias: 4.3729e-02
# Gradient norm for conv3.weight: 6.9217e-01
# Gradient norm for conv3.bias: 4.0779e-02
# Gradient norm for fc1.weight: 1.4379e+00
# Gradient norm for fc1.bias: 4.4273e-02
# Gradient norm for fc2.weight: 2.2645e+00
# Gradient norm for fc2.bias: 1.0889e-01
# Gradient norm for conv1.weight: 4.2394e-01
# Gradient norm for conv1.bias: 7.3320e-02
# Gradient norm for conv2.weight: 8.4836e-01
# Gradient norm for conv2.bias: 6.3466e-02
# Gradient norm for conv3.weight: 7.2636e-01
# Gradient norm for conv3.bias: 4.6864e-02
# Gradient norm for fc1.weight: 1.0776e+00
# Gradient norm for fc1.bias: 3.2687e-02
# Gradient norm for fc2.weight: 1.8341e+00
# Gradient norm for fc2.bias: 8.9098e-02
# Gradient norm for conv1.weight: 7.3843e-01
# Gradient norm for conv1.bias: 2.4772e-01
# Gradient norm for conv2.weight: 1.7124e+00
# Gradient norm for conv2.bias: 1.5405e-01
# Gradient norm for conv3.weight: 1.0520e+00
# Gradient norm for conv3.bias: 6.6497e-02
# Gradient norm for fc1.weight: 1.4283e+00
# Gradient norm for fc1.bias: 4.2403e-02
# Gradient norm for fc2.weight: 2.5682e+00
# Gradient norm for fc2.bias: 1.1318e-01
# Gradient norm for conv1.weight: 6.1232e-01
# Gradient norm for conv1.bias: 1.4137e-01
# Gradient norm for conv2.weight: 1.5597e+00
# Gradient norm for conv2.bias: 1.2906e-01
# Gradient norm for conv3.weight: 1.1716e+00
# Gradient norm for conv3.bias: 7.6946e-02
# Gradient norm for fc1.weight: 1.4203e+00
# Gradient norm for fc1.bias: 4.2058e-02
# Gradient norm for fc2.weight: 2.2815e+00
# Gradient norm for fc2.bias: 1.0007e-01
# Gradient norm for conv1.weight: 7.4862e-01
# Gradient norm for conv1.bias: 1.6942e-01
# Gradient norm for conv2.weight: 1.4930e+00
# Gradient norm for conv2.bias: 1.0387e-01
# Gradient norm for conv3.weight: 1.1761e+00
# Gradient norm for conv3.bias: 6.5582e-02
# Gradient norm for fc1.weight: 1.8800e+00
# Gradient norm for fc1.bias: 5.3021e-02
# Gradient norm for fc2.weight: 3.3158e+00
# Gradient norm for fc2.bias: 1.3934e-01
# Gradient norm for conv1.weight: 1.1827e+00
# Gradient norm for conv1.bias: 4.1828e-01
# Gradient norm for conv2.weight: 2.7710e+00
# Gradient norm for conv2.bias: 2.4639e-01
# Gradient norm for conv3.weight: 1.4816e+00
# Gradient norm for conv3.bias: 9.8628e-02
# Gradient norm for fc1.weight: 1.8164e+00
# Gradient norm for fc1.bias: 5.3715e-02
# Gradient norm for fc2.weight: 3.4094e+00
# Gradient norm for fc2.bias: 1.5300e-01
# Gradient norm for conv1.weight: 5.6356e-01
# Gradient norm for conv1.bias: 1.4339e-01
# Gradient norm for conv2.weight: 1.0098e+00
# Gradient norm for conv2.bias: 8.9363e-02
# Gradient norm for conv3.weight: 6.4319e-01
# Gradient norm for conv3.bias: 4.1025e-02
# Gradient norm for fc1.weight: 1.3496e+00
# Gradient norm for fc1.bias: 3.8499e-02
# Gradient norm for fc2.weight: 2.3623e+00
# Gradient norm for fc2.bias: 1.0180e-01
# Gradient norm for conv1.weight: 3.8628e-01
# Gradient norm for conv1.bias: 7.6514e-02
# Gradient norm for conv2.weight: 8.5585e-01
# Gradient norm for conv2.bias: 7.8767e-02
# Gradient norm for conv3.weight: 7.1692e-01
# Gradient norm for conv3.bias: 5.3745e-02
# Gradient norm for fc1.weight: 1.2436e+00
# Gradient norm for fc1.bias: 3.9914e-02
# Gradient norm for fc2.weight: 2.1661e+00
# Gradient norm for fc2.bias: 1.0544e-01
# Gradient norm for conv1.weight: 4.8408e-01
# Gradient norm for conv1.bias: 1.0174e-01
# Gradient norm for conv2.weight: 9.6354e-01
# Gradient norm for conv2.bias: 9.1581e-02
# Gradient norm for conv3.weight: 7.1598e-01
# Gradient norm for conv3.bias: 6.0039e-02
# Gradient norm for fc1.weight: 1.1516e+00
# Gradient norm for fc1.bias: 3.6587e-02
# Gradient norm for fc2.weight: 1.9235e+00
# Gradient norm for fc2.bias: 8.9262e-02
# Gradient norm for conv1.weight: 5.9509e-01
# Gradient norm for conv1.bias: 1.0838e-01
# Gradient norm for conv2.weight: 1.1736e+00
# Gradient norm for conv2.bias: 7.0953e-02
# Gradient norm for conv3.weight: 8.3198e-01
# Gradient norm for conv3.bias: 4.6843e-02
# Gradient norm for fc1.weight: 1.3933e+00
# Gradient norm for fc1.bias: 4.1295e-02
# Gradient norm for fc2.weight: 2.6089e+00
# Gradient norm for fc2.bias: 1.1124e-01
# Gradient norm for conv1.weight: 5.7881e-01
# Gradient norm for conv1.bias: 2.2374e-01
# Gradient norm for conv2.weight: 1.7008e+00
# Gradient norm for conv2.bias: 1.8644e-01
# Gradient norm for conv3.weight: 1.1766e+00
# Gradient norm for conv3.bias: 1.0006e-01
# Gradient norm for fc1.weight: 1.6297e+00
# Gradient norm for fc1.bias: 5.7765e-02
# Gradient norm for fc2.weight: 2.7972e+00
# Gradient norm for fc2.bias: 1.4622e-01
# Gradient norm for conv1.weight: 3.5966e-01
# Gradient norm for conv1.bias: 8.0449e-02
# Gradient norm for conv2.weight: 8.8371e-01
# Gradient norm for conv2.bias: 7.3813e-02
# Gradient norm for conv3.weight: 7.1434e-01
# Gradient norm for conv3.bias: 4.4673e-02
# Gradient norm for fc1.weight: 1.2689e+00
# Gradient norm for fc1.bias: 3.9146e-02
# Gradient norm for fc2.weight: 2.3692e+00
# Gradient norm for fc2.bias: 1.0580e-01
# Gradient norm for conv1.weight: 1.0856e+00
# Gradient norm for conv1.bias: 2.7602e-01
# Gradient norm for conv2.weight: 2.3687e+00
# Gradient norm for conv2.bias: 1.6357e-01
# Gradient norm for conv3.weight: 1.2344e+00
# Gradient norm for conv3.bias: 6.7040e-02
# Gradient norm for fc1.weight: 1.4550e+00
# Gradient norm for fc1.bias: 4.6467e-02
# Gradient norm for fc2.weight: 2.5645e+00
# Gradient norm for fc2.bias: 1.1829e-01
# Gradient norm for conv1.weight: 3.3620e-01
# Gradient norm for conv1.bias: 4.4608e-02
# Gradient norm for conv2.weight: 6.0314e-01
# Gradient norm for conv2.bias: 3.4985e-02
# Gradient norm for conv3.weight: 5.1691e-01
# Gradient norm for conv3.bias: 2.7758e-02
# Gradient norm for fc1.weight: 1.1422e+00
# Gradient norm for fc1.bias: 3.6634e-02
# Gradient norm for fc2.weight: 2.0844e+00
# Gradient norm for fc2.bias: 1.0417e-01
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 322
#     320 if 'ipykernel' in sys.argv[0]:
#     321     sys.argv = ['scout_opt_cifar10.py', '--gpu']
# --> 322 main()
#
# Cell In[10], line 289, in main()
#     287 print(f"\nEpoch {ep}/{args.epochs}")
#     288 start = time.time()
# --> 289 train_one_epoch(model, train_loader, criterion, opt, device)
#     290 val_loss, val_acc = evaluate(model, test_loader, criterion, device)
#     291 print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
#
# Cell In[10], line 192, in train_one_epoch(model, loader, criterion, opt, device, log_every)
#     189     loss.backward()
#     190     return loss
# --> 192 loss = opt.step(closure)
#     194 running += loss.item()
#     195 if (i + 1) % log_every == 0:
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# Cell In[10], line 141, in ModifiedScoutOptimizer.step(self, closure)
#     138 best_scale = 0
#     140 for d in directions:
# --> 141     tracked_loss, d_dir, d_steps = self._track_direction(d, closure, self.steps)
#     142     if tracked_loss < best_loss:
#     143         best_loss = tracked_loss
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[10], line 109, in ModifiedScoutOptimizer._track_direction(self, direction, closure, max_steps)
#     107 for i in range(1, max_steps + 1):
#     108     self._apply_delta(direction, self.radius)
# --> 109     loss = closure()
#     110     if loss < best_loss:
#     111         best_loss = loss
#
# Cell In[10], line 188, in train_one_epoch.<locals>.closure()
#     186 loss = criterion(out, y)
#     187 if not loss.requires_grad:
# --> 188     raise RuntimeError("Loss does not require grad. Check computation graph.")
#     189 loss.backward()
#     190 return loss
#
# RuntimeError: Loss does not require grad. Check computation graph.

# %%
"""scout_opt_cifar10.py

Quick‑and‑dirty *large(-ish)* demo of the scout–guided optimizer on CIFAR‑10.

• Dataset  : CIFAR‑10 (50 k train / 10 k test, 32×32 colour)
• Model    : lightweight CNN (~0.6 M params)
• Baseline : Adam
• ScoutOpt : wraps Adam, periodically probes 2 directions
             (current grad + one random orthogonal) with
             a 1‑step look‑ahead on the same mini‑batch.

Run from a Jupyter cell (accepts the stray -f arg) or from CLI:
    python scout_opt_cifar10.py --gpu  
-------------------------------------------------------"""

import argparse, time, pathlib, random, sys
from typing import List

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# ------------------------------------------------------------------ #
#  1. A small-ish CNN                                                #
# ------------------------------------------------------------------ #
class SmallCNN(nn.Module):
    def __init__(self, n_classes: int = 10):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.pool  = nn.MaxPool2d(2, 2)
        self.fc1   = nn.Linear(256 * 4 * 4, 256)
        self.fc2   = nn.Linear(256, n_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # 32→16
        x = self.pool(F.relu(self.conv2(x)))  # 16→8
        x = self.pool(F.relu(self.conv3(x)))  # 8 →4
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# ------------------------------------------------------------------ #
#  2. Scout‑guided Optimizer                                         #
# ------------------------------------------------------------------ #
import torch
import torch.nn as nn
from typing import List

class ModifiedScoutOptimizer(torch.optim.Optimizer):
    """
    Extended Scout Optimizer with multi-step probes along ±orthogonal directions.
    Now supports walking 'scout_steps' forward in each direction before deciding.
    """

    def __init__(
        self,
        params,
        base_opt_cls,
        *,
        lr=3e-4,
        scout_every=100,
        scout_radius=5e-4,
        scout_steps=100,
        **base_kwargs
    ):
        param_list = list(params)
        self.base = base_opt_cls(param_list, lr=lr, **base_kwargs)
        super().__init__(param_list, defaults=dict(lr=lr))
        self.s_every = scout_every
        self.radius = scout_radius
        self.steps = scout_steps
        self._step_id = 0
        self._params = param_list

    @staticmethod
    @torch.no_grad()
    def _flatten(tensors: List[torch.Tensor]):
        return torch.cat([t.reshape(-1) for t in tensors])

    @torch.no_grad()
    def _apply_delta(self, vec_flat: torch.Tensor, coef: float):
        offset = 0
        for p in self._params:
            n = p.numel()
            p.add_(vec_flat[offset:offset+n].view_as(p), alpha=coef)
            offset += n

    @staticmethod
    @torch.no_grad()
    def _rand_orthogonal(base: torch.Tensor):
        r = torch.randn_like(base)
        proj = (r @ base) / (base @ base + 1e-12)
        ortho = r - proj * base
        return ortho / (ortho.norm() + 1e-12)

    @torch.no_grad()
    def _track_direction(self, direction: torch.Tensor, closure, max_steps: int):
        best_loss = float('inf')
        best_step = 0

        for i in range(1, max_steps + 1):
            self._apply_delta(direction, self.radius)
            loss = closure()
            if loss < best_loss:
                best_loss = loss
                best_step = i

        self._apply_delta(direction, -self.radius * best_step)
        return best_loss, direction, best_step

    def step(self, closure=None):
        if closure is None:
            raise RuntimeError("ModifiedScoutOptimizer needs a closure that returns loss and does backward()")

        loss = closure()
        self._step_id += 1

        if self._step_id % self.s_every == 0:
            grad_flat = self._flatten([p.grad for p in self._params])
            grad_norm = grad_flat.norm() + 1e-12
            grad_dir = grad_flat / grad_norm
            ortho_dir = self._rand_orthogonal(grad_dir)

            directions = [
                grad_dir,
                ortho_dir,
                -ortho_dir
            ]

            best_loss = loss.item()
            best_dir = None
            best_scale = 0

            for d in directions:
                tracked_loss, d_dir, d_steps = self._track_direction(d, closure, self.steps)
                if tracked_loss < best_loss:
                    best_loss = tracked_loss
                    best_dir = d_dir
                    best_scale = d_steps

            if best_dir is not None:
                new_grad = best_dir * grad_norm
                offset = 0
                for p in self._params:
                    n = p.numel()
                    p.grad.copy_(new_grad[offset:offset+n].view_as(p))
                    offset += n

        self.base.step()
        return loss


# ------------------------------------------------------------------ #
#  3. Training / evaluation loops                                    #
# ------------------------------------------------------------------ #
@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    tot_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        out = model(x)
        tot_loss += criterion(out, y).item() * x.size(0)
        pred = out.argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)
    return tot_loss / total, correct / total


def train_one_epoch(model, loader, criterion, opt, device, log_every=100):
    model.train()
    running = 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)

        # Move x and y to new scope for each closure evaluation
        def closure():
            opt.base.zero_grad()
            with torch.enable_grad():
                out = model(x)
                loss = criterion(out, y)
            if not loss.requires_grad:
                raise RuntimeError("Loss does not require grad. Check computation graph.")
            loss.backward()
            return loss

        loss = opt.step(closure)

        running += loss.item()
        if (i + 1) % log_every == 0:
            print(f"  batch {i+1}/{len(loader)}  loss {running/log_every:.3f}")
            running = 0.0

        # Debug: ensure gradient exists
        for name, param in model.named_parameters():
            if param.grad is None:
                print(f"WARNING: No gradient for {name}")
            else:
                print(f"Gradient norm for {name}: {param.grad.norm().item():.4e}")

def run_baseline_adam(epochs=6, batch=128, lr=3e-4, results=None):
    print("\nBaseline: Adam")
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])
    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)
    train_loader = DataLoader(train_set, batch_size=batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,   shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=1e-4)

    for ep in range(1, epochs+1):
        print(f"\nEpoch {ep}/{epochs}")
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}")
        if results is not None:
            results['adam_loss'].append(val_loss)
            results['adam_acc'].append(val_acc)

# ------------------------------------------------------------------ #
#  5. Main                                                           #
# ------------------------------------------------------------------ #

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--epochs', type=int, default=50)
    parser.add_argument('--batch',  type=int, default=128)
    parser.add_argument('--lr',     type=float, default=3e-4)
    parser.add_argument('--scout_every',  type=int, default=100)
    parser.add_argument('--scout_radius', type=float, default=5e-4)
    parser.add_argument('--gpu', action='store_true')
    args, _ = parser.parse_known_args()

    args.gpu = True  # Force GPU usage in Jupyter
    device = torch.device('cuda' if args.gpu and torch.cuda.is_available() else 'cpu')
    print('Using CUDA:', torch.cuda.is_available(), 'Device:', device)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010))
    ])

    root = str(pathlib.Path.home() / ".torchdata")
    train_set = datasets.CIFAR10(root=root, train=True,  download=True, transform=transform)
    test_set  = datasets.CIFAR10(root=root, train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, batch_size=args.batch, shuffle=True,  num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_set,  batch_size=256,       shuffle=False, num_workers=2, pin_memory=True)

    model = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    opt = ModifiedScoutOptimizer(
        model.parameters(), optim.Adam,
        lr=args.lr,
        scout_every=args.scout_every,
        scout_radius=args.scout_radius,
        scout_steps=50,
        betas=(0.9, 0.999),
        weight_decay=1e-4
    )

    results = {'scout_loss': [], 'scout_acc': [], 'adam_loss': [], 'adam_acc': []}

    for ep in range(1, args.epochs+1):
        print(f"\nEpoch {ep}/{args.epochs}")
        start = time.time()
        train_one_epoch(model, train_loader, criterion, opt, device)
        val_loss, val_acc = evaluate(model, test_loader, criterion, device)
        print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
        results['scout_loss'].append(val_loss)
        results['scout_acc'].append(val_acc)

    torch.save(model.state_dict(), "scout_cnn.pth")
    print("Model saved to scout_cnn.pth")

    run_baseline_adam(epochs=args.epochs, batch=args.batch, lr=args.lr, results=results)

    print("\nFinal comparison table:")
    for i in range(args.epochs):
        print(f"Epoch {i+1:>2}:  Scout acc = {results['scout_acc'][i]*100:.2f}%  |  Adam acc = {results['adam_acc'][i]*100:.2f}%")

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(results['scout_loss'], label='Scout Loss')
    plt.plot(results['adam_loss'],  label='Adam Loss')
    plt.legend()
    plt.title("Validation Loss")

    plt.subplot(1, 2, 2)
    plt.plot(results['scout_acc'], label='Scout Acc')
    plt.plot(results['adam_acc'],  label='Adam Acc')
    plt.legend()
    plt.title("Validation Accuracy")
    plt.tight_layout()
    plt.show()

if __name__ == '__main__':
    if 'ipykernel' in sys.argv[0]:
        sys.argv = ['scout_opt_cifar10.py', '--gpu']
    main()
# Out:
# Using CUDA: True Device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch 1/50
# Gradient norm for conv1.weight: 2.4639e-02
# Gradient norm for conv1.bias: 3.3465e-03
# Gradient norm for conv2.weight: 1.1100e-01
# Gradient norm for conv2.bias: 6.4690e-03
# Gradient norm for conv3.weight: 1.5646e-01
# Gradient norm for conv3.bias: 1.5207e-02
# Gradient norm for fc1.weight: 3.0689e-01
# Gradient norm for fc1.bias: 2.8272e-02
# Gradient norm for fc2.weight: 7.3349e-02
# Gradient norm for fc2.bias: 7.0145e-02
# Gradient norm for conv1.weight: 2.2018e-02
# Gradient norm for conv1.bias: 4.7214e-03
# Gradient norm for conv2.weight: 1.3160e-01
# Gradient norm for conv2.bias: 1.0567e-02
# Gradient norm for conv3.weight: 1.8447e-01
# Gradient norm for conv3.bias: 2.2075e-02
# Gradient norm for fc1.weight: 3.9826e-01
# Gradient norm for fc1.bias: 4.4352e-02
# Gradient norm for fc2.weight: 1.4893e-01
# Gradient norm for fc2.bias: 1.0585e-01
# Gradient norm for conv1.weight: 2.7568e-02
# Gradient norm for conv1.bias: 4.1883e-03
# Gradient norm for conv2.weight: 1.4494e-01
# Gradient norm for conv2.bias: 9.5932e-03
# Gradient norm for conv3.weight: 2.1073e-01
# Gradient norm for conv3.bias: 2.1434e-02
# Gradient norm for fc1.weight: 4.6886e-01
# Gradient norm for fc1.bias: 4.0706e-02
# Gradient norm for fc2.weight: 1.9319e-01
# Gradient norm for fc2.bias: 8.9736e-02
# Gradient norm for conv1.weight: 3.3525e-02
# Gradient norm for conv1.bias: 4.8469e-03
# Gradient norm for conv2.weight: 1.3905e-01
# Gradient norm for conv2.bias: 7.7862e-03
# Gradient norm for conv3.weight: 1.7276e-01
# Gradient norm for conv3.bias: 1.5885e-02
# Gradient norm for fc1.weight: 3.4773e-01
# Gradient norm for fc1.bias: 2.9977e-02
# Gradient norm for fc2.weight: 1.5822e-01
# Gradient norm for fc2.bias: 6.2244e-02
# Gradient norm for conv1.weight: 4.8030e-02
# Gradient norm for conv1.bias: 6.5173e-03
# Gradient norm for conv2.weight: 1.7234e-01
# Gradient norm for conv2.bias: 1.1076e-02
# Gradient norm for conv3.weight: 2.1594e-01
# Gradient norm for conv3.bias: 2.0032e-02
# Gradient norm for fc1.weight: 4.9347e-01
# Gradient norm for fc1.bias: 3.9325e-02
# Gradient norm for fc2.weight: 2.8907e-01
# Gradient norm for fc2.bias: 1.0055e-01
# Gradient norm for conv1.weight: 8.6463e-02
# Gradient norm for conv1.bias: 1.0640e-02
# Gradient norm for conv2.weight: 2.5862e-01
# Gradient norm for conv2.bias: 1.6138e-02
# Gradient norm for conv3.weight: 2.5234e-01
# Gradient norm for conv3.bias: 2.1971e-02
# Gradient norm for fc1.weight: 4.3602e-01
# Gradient norm for fc1.bias: 2.9381e-02
# Gradient norm for fc2.weight: 2.7570e-01
# Gradient norm for fc2.bias: 7.0444e-02
# Gradient norm for conv1.weight: 5.3124e-02
# Gradient norm for conv1.bias: 9.6151e-03
# Gradient norm for conv2.weight: 2.1752e-01
# Gradient norm for conv2.bias: 1.8571e-02
# Gradient norm for conv3.weight: 2.6715e-01
# Gradient norm for conv3.bias: 3.0278e-02
# Gradient norm for fc1.weight: 6.0005e-01
# Gradient norm for fc1.bias: 5.1709e-02
# Gradient norm for fc2.weight: 4.3498e-01
# Gradient norm for fc2.bias: 1.2963e-01
# Gradient norm for conv1.weight: 6.4918e-02
# Gradient norm for conv1.bias: 1.3577e-02
# Gradient norm for conv2.weight: 2.3732e-01
# Gradient norm for conv2.bias: 1.9170e-02
# Gradient norm for conv3.weight: 2.6210e-01
# Gradient norm for conv3.bias: 2.6947e-02
# Gradient norm for fc1.weight: 5.1076e-01
# Gradient norm for fc1.bias: 3.7562e-02
# Gradient norm for fc2.weight: 3.4629e-01
# Gradient norm for fc2.bias: 8.5334e-02
# Gradient norm for conv1.weight: 9.9013e-02
# Gradient norm for conv1.bias: 1.9546e-02
# Gradient norm for conv2.weight: 3.2211e-01
# Gradient norm for conv2.bias: 2.9676e-02
# Gradient norm for conv3.weight: 3.3707e-01
# Gradient norm for conv3.bias: 3.9297e-02
# Gradient norm for fc1.weight: 6.9243e-01
# Gradient norm for fc1.bias: 5.1724e-02
# Gradient norm for fc2.weight: 5.4611e-01
# Gradient norm for fc2.bias: 1.3301e-01
# Gradient norm for conv1.weight: 6.1772e-02
# Gradient norm for conv1.bias: 8.9947e-03
# Gradient norm for conv2.weight: 1.8157e-01
# Gradient norm for conv2.bias: 1.3068e-02
# Gradient norm for conv3.weight: 2.3903e-01
# Gradient norm for conv3.bias: 2.5381e-02
# Gradient norm for fc1.weight: 6.0391e-01
# Gradient norm for fc1.bias: 4.3277e-02
# Gradient norm for fc2.weight: 4.9068e-01
# Gradient norm for fc2.bias: 1.1063e-01
# Gradient norm for conv1.weight: 7.4113e-02
# Gradient norm for conv1.bias: 1.0576e-02
# Gradient norm for conv2.weight: 1.9639e-01
# Gradient norm for conv2.bias: 1.2320e-02
# Gradient norm for conv3.weight: 2.2682e-01
# Gradient norm for conv3.bias: 2.1357e-02
# Gradient norm for fc1.weight: 5.6576e-01
# Gradient norm for fc1.bias: 3.4861e-02
# Gradient norm for fc2.weight: 4.8745e-01
# Gradient norm for fc2.bias: 8.6461e-02
# Gradient norm for conv1.weight: 1.7206e-01
# Gradient norm for conv1.bias: 2.8847e-02
# Gradient norm for conv2.weight: 4.8228e-01
# Gradient norm for conv2.bias: 3.3646e-02
# Gradient norm for conv3.weight: 3.8107e-01
# Gradient norm for conv3.bias: 3.3738e-02
# Gradient norm for fc1.weight: 8.3735e-01
# Gradient norm for fc1.bias: 4.7402e-02
# Gradient norm for fc2.weight: 7.0474e-01
# Gradient norm for fc2.bias: 1.1198e-01
# Gradient norm for conv1.weight: 1.7699e-01
# Gradient norm for conv1.bias: 3.9948e-02
# Gradient norm for conv2.weight: 5.2719e-01
# Gradient norm for conv2.bias: 4.3392e-02
# Gradient norm for conv3.weight: 4.0943e-01
# Gradient norm for conv3.bias: 3.5416e-02
# Gradient norm for fc1.weight: 6.1486e-01
# Gradient norm for fc1.bias: 2.9042e-02
# Gradient norm for fc2.weight: 4.9490e-01
# Gradient norm for fc2.bias: 5.9450e-02
# Gradient norm for conv1.weight: 1.4593e-01
# Gradient norm for conv1.bias: 1.6924e-02
# Gradient norm for conv2.weight: 3.3450e-01
# Gradient norm for conv2.bias: 1.7649e-02
# Gradient norm for conv3.weight: 3.0001e-01
# Gradient norm for conv3.bias: 2.1908e-02
# Gradient norm for fc1.weight: 7.1364e-01
# Gradient norm for fc1.bias: 3.4105e-02
# Gradient norm for fc2.weight: 6.8389e-01
# Gradient norm for fc2.bias: 9.7916e-02
# Gradient norm for conv1.weight: 1.8965e-01
# Gradient norm for conv1.bias: 3.3278e-02
# Gradient norm for conv2.weight: 4.6981e-01
# Gradient norm for conv2.bias: 3.4801e-02
# Gradient norm for conv3.weight: 3.5039e-01
# Gradient norm for conv3.bias: 2.8141e-02
# Gradient norm for fc1.weight: 6.2802e-01
# Gradient norm for fc1.bias: 3.3050e-02
# Gradient norm for fc2.weight: 5.9064e-01
# Gradient norm for fc2.bias: 8.2292e-02
# Gradient norm for conv1.weight: 1.8081e-01
# Gradient norm for conv1.bias: 4.3123e-02
# Gradient norm for conv2.weight: 5.2142e-01
# Gradient norm for conv2.bias: 3.9944e-02
# Gradient norm for conv3.weight: 4.0178e-01
# Gradient norm for conv3.bias: 2.7866e-02
# Gradient norm for fc1.weight: 7.8581e-01
# Gradient norm for fc1.bias: 2.9707e-02
# Gradient norm for fc2.weight: 7.5881e-01
# Gradient norm for fc2.bias: 6.9099e-02
# Gradient norm for conv1.weight: 1.7030e-01
# Gradient norm for conv1.bias: 3.3363e-02
# Gradient norm for conv2.weight: 4.7753e-01
# Gradient norm for conv2.bias: 3.2766e-02
# Gradient norm for conv3.weight: 3.9968e-01
# Gradient norm for conv3.bias: 2.6814e-02
# Gradient norm for fc1.weight: 8.7114e-01
# Gradient norm for fc1.bias: 3.4025e-02
# Gradient norm for fc2.weight: 1.0105e+00
# Gradient norm for fc2.bias: 8.1626e-02
# Gradient norm for conv1.weight: 2.6558e-01
# Gradient norm for conv1.bias: 3.9231e-02
# Gradient norm for conv2.weight: 6.1026e-01
# Gradient norm for conv2.bias: 4.2039e-02
# Gradient norm for conv3.weight: 5.4626e-01
# Gradient norm for conv3.bias: 4.7549e-02
# Gradient norm for fc1.weight: 1.2287e+00
# Gradient norm for fc1.bias: 5.4788e-02
# Gradient norm for fc2.weight: 1.4837e+00
# Gradient norm for fc2.bias: 1.4622e-01
# Gradient norm for conv1.weight: 5.0207e-01
# Gradient norm for conv1.bias: 1.4416e-01
# Gradient norm for conv2.weight: 1.3431e+00
# Gradient norm for conv2.bias: 1.2936e-01
# Gradient norm for conv3.weight: 8.1817e-01
# Gradient norm for conv3.bias: 7.2750e-02
# Gradient norm for fc1.weight: 1.1989e+00
# Gradient norm for fc1.bias: 4.2999e-02
# Gradient norm for fc2.weight: 1.4789e+00
# Gradient norm for fc2.bias: 1.0433e-01
# Gradient norm for conv1.weight: 5.5928e-01
# Gradient norm for conv1.bias: 1.1861e-01
# Gradient norm for conv2.weight: 1.2242e+00
# Gradient norm for conv2.bias: 9.5548e-02
# Gradient norm for conv3.weight: 7.4594e-01
# Gradient norm for conv3.bias: 5.3952e-02
# Gradient norm for fc1.weight: 1.3073e+00
# Gradient norm for fc1.bias: 3.9983e-02
# Gradient norm for fc2.weight: 1.5450e+00
# Gradient norm for fc2.bias: 9.8078e-02
# Gradient norm for conv1.weight: 3.4690e-01
# Gradient norm for conv1.bias: 7.3985e-02
# Gradient norm for conv2.weight: 1.0209e+00
# Gradient norm for conv2.bias: 6.8437e-02
# Gradient norm for conv3.weight: 7.6864e-01
# Gradient norm for conv3.bias: 4.4288e-02
# Gradient norm for fc1.weight: 1.7489e+00
# Gradient norm for fc1.bias: 5.6182e-02
# Gradient norm for fc2.weight: 2.1698e+00
# Gradient norm for fc2.bias: 1.4651e-01
# Gradient norm for conv1.weight: 5.9930e-01
# Gradient norm for conv1.bias: 1.7298e-01
# Gradient norm for conv2.weight: 1.7835e+00
# Gradient norm for conv2.bias: 1.5338e-01
# Gradient norm for conv3.weight: 1.1892e+00
# Gradient norm for conv3.bias: 8.3431e-02
# Gradient norm for fc1.weight: 1.7292e+00
# Gradient norm for fc1.bias: 5.4603e-02
# Gradient norm for fc2.weight: 2.1402e+00
# Gradient norm for fc2.bias: 1.3797e-01
# Gradient norm for conv1.weight: 2.7802e-01
# Gradient norm for conv1.bias: 3.8507e-02
# Gradient norm for conv2.weight: 5.2804e-01
# Gradient norm for conv2.bias: 3.4260e-02
# Gradient norm for conv3.weight: 4.8270e-01
# Gradient norm for conv3.bias: 3.3062e-02
# Gradient norm for fc1.weight: 1.3301e+00
# Gradient norm for fc1.bias: 3.7891e-02
# Gradient norm for fc2.weight: 1.6364e+00
# Gradient norm for fc2.bias: 9.6662e-02
# Gradient norm for conv1.weight: 6.1417e-01
# Gradient norm for conv1.bias: 1.7125e-01
# Gradient norm for conv2.weight: 1.6526e+00
# Gradient norm for conv2.bias: 1.4732e-01
# Gradient norm for conv3.weight: 1.1775e+00
# Gradient norm for conv3.bias: 8.7403e-02
# Gradient norm for fc1.weight: 1.9896e+00
# Gradient norm for fc1.bias: 6.5201e-02
# Gradient norm for fc2.weight: 2.3518e+00
# Gradient norm for fc2.bias: 1.5307e-01
# Gradient norm for conv1.weight: 7.7616e-01
# Gradient norm for conv1.bias: 2.5301e-01
# Gradient norm for conv2.weight: 2.2305e+00
# Gradient norm for conv2.bias: 2.0436e-01
# Gradient norm for conv3.weight: 1.4111e+00
# Gradient norm for conv3.bias: 1.0388e-01
# Gradient norm for fc1.weight: 2.1137e+00
# Gradient norm for fc1.bias: 6.2436e-02
# Gradient norm for fc2.weight: 2.7559e+00
# Gradient norm for fc2.bias: 1.4803e-01
# Gradient norm for conv1.weight: 4.5631e-01
# Gradient norm for conv1.bias: 1.2630e-01
# Gradient norm for conv2.weight: 1.2942e+00
# Gradient norm for conv2.bias: 1.1057e-01
# Gradient norm for conv3.weight: 9.2774e-01
# Gradient norm for conv3.bias: 6.4343e-02
# Gradient norm for fc1.weight: 1.7219e+00
# Gradient norm for fc1.bias: 5.0817e-02
# Gradient norm for fc2.weight: 2.2971e+00
# Gradient norm for fc2.bias: 1.3132e-01
# Gradient norm for conv1.weight: 7.0407e-01
# Gradient norm for conv1.bias: 2.3427e-01
# Gradient norm for conv2.weight: 2.0588e+00
# Gradient norm for conv2.bias: 1.9935e-01
# Gradient norm for conv3.weight: 1.2751e+00
# Gradient norm for conv3.bias: 1.0247e-01
# Gradient norm for fc1.weight: 1.4981e+00
# Gradient norm for fc1.bias: 4.7234e-02
# Gradient norm for fc2.weight: 1.6423e+00
# Gradient norm for fc2.bias: 9.8351e-02
# Gradient norm for conv1.weight: 6.3607e-01
# Gradient norm for conv1.bias: 1.7610e-01
# Gradient norm for conv2.weight: 1.8367e+00
# Gradient norm for conv2.bias: 1.5157e-01
# Gradient norm for conv3.weight: 1.2066e+00
# Gradient norm for conv3.bias: 8.2477e-02
# Gradient norm for fc1.weight: 1.8037e+00
# Gradient norm for fc1.bias: 5.3748e-02
# Gradient norm for fc2.weight: 2.0766e+00
# Gradient norm for fc2.bias: 1.1915e-01
# Gradient norm for conv1.weight: 1.8770e-01
# Gradient norm for conv1.bias: 2.3463e-02
# Gradient norm for conv2.weight: 3.6290e-01
# Gradient norm for conv2.bias: 1.8938e-02
# Gradient norm for conv3.weight: 3.5375e-01
# Gradient norm for conv3.bias: 2.0177e-02
# Gradient norm for fc1.weight: 8.8677e-01
# Gradient norm for fc1.bias: 2.5452e-02
# Gradient norm for fc2.weight: 1.0954e+00
# Gradient norm for fc2.bias: 6.6712e-02
# Gradient norm for conv1.weight: 9.7077e-01
# Gradient norm for conv1.bias: 3.0344e-01
# Gradient norm for conv2.weight: 2.7198e+00
# Gradient norm for conv2.bias: 2.4393e-01
# Gradient norm for conv3.weight: 1.6185e+00
# Gradient norm for conv3.bias: 1.2628e-01
# Gradient norm for fc1.weight: 2.0371e+00
# Gradient norm for fc1.bias: 7.4734e-02
# Gradient norm for fc2.weight: 2.5064e+00
# Gradient norm for fc2.bias: 1.6540e-01
# Gradient norm for conv1.weight: 7.8006e-01
# Gradient norm for conv1.bias: 2.8807e-01
# Gradient norm for conv2.weight: 2.3725e+00
# Gradient norm for conv2.bias: 2.3074e-01
# Gradient norm for conv3.weight: 1.3913e+00
# Gradient norm for conv3.bias: 1.1798e-01
# Gradient norm for fc1.weight: 1.6644e+00
# Gradient norm for fc1.bias: 6.3450e-02
# Gradient norm for fc2.weight: 1.9566e+00
# Gradient norm for fc2.bias: 1.3876e-01
# Gradient norm for conv1.weight: 3.9083e-01
# Gradient norm for conv1.bias: 1.0729e-01
# Gradient norm for conv2.weight: 1.1210e+00
# Gradient norm for conv2.bias: 9.0423e-02
# Gradient norm for conv3.weight: 7.3794e-01
# Gradient norm for conv3.bias: 5.2128e-02
# Gradient norm for fc1.weight: 1.2763e+00
# Gradient norm for fc1.bias: 4.5330e-02
# Gradient norm for fc2.weight: 1.5837e+00
# Gradient norm for fc2.bias: 1.0482e-01
# Gradient norm for conv1.weight: 4.2507e-01
# Gradient norm for conv1.bias: 1.1890e-01
# Gradient norm for conv2.weight: 1.2008e+00
# Gradient norm for conv2.bias: 1.0078e-01
# Gradient norm for conv3.weight: 8.1496e-01
# Gradient norm for conv3.bias: 6.1908e-02
# Gradient norm for fc1.weight: 1.4483e+00
# Gradient norm for fc1.bias: 5.7655e-02
# Gradient norm for fc2.weight: 2.1262e+00
# Gradient norm for fc2.bias: 1.6643e-01
# Gradient norm for conv1.weight: 3.0563e-01
# Gradient norm for conv1.bias: 6.4910e-02
# Gradient norm for conv2.weight: 7.0411e-01
# Gradient norm for conv2.bias: 5.4433e-02
# Gradient norm for conv3.weight: 5.4154e-01
# Gradient norm for conv3.bias: 3.6919e-02
# Gradient norm for fc1.weight: 1.2793e+00
# Gradient norm for fc1.bias: 4.3302e-02
# Gradient norm for fc2.weight: 2.0311e+00
# Gradient norm for fc2.bias: 1.3516e-01
# Gradient norm for conv1.weight: 7.9938e-01
# Gradient norm for conv1.bias: 2.4207e-01
# Gradient norm for conv2.weight: 2.2088e+00
# Gradient norm for conv2.bias: 1.9697e-01
# Gradient norm for conv3.weight: 1.2596e+00
# Gradient norm for conv3.bias: 1.0455e-01
# Gradient norm for fc1.weight: 1.5327e+00
# Gradient norm for fc1.bias: 5.6064e-02
# Gradient norm for fc2.weight: 1.7758e+00
# Gradient norm for fc2.bias: 1.2021e-01
# Gradient norm for conv1.weight: 4.6122e-01
# Gradient norm for conv1.bias: 1.4076e-01
# Gradient norm for conv2.weight: 1.4575e+00
# Gradient norm for conv2.bias: 1.1596e-01
# Gradient norm for conv3.weight: 9.2380e-01
# Gradient norm for conv3.bias: 6.3526e-02
# Gradient norm for fc1.weight: 1.1462e+00
# Gradient norm for fc1.bias: 3.9543e-02
# Gradient norm for fc2.weight: 1.3325e+00
# Gradient norm for fc2.bias: 8.6636e-02
# Gradient norm for conv1.weight: 2.1100e-01
# Gradient norm for conv1.bias: 6.4264e-02
# Gradient norm for conv2.weight: 5.1688e-01
# Gradient norm for conv2.bias: 5.3354e-02
# Gradient norm for conv3.weight: 4.3471e-01
# Gradient norm for conv3.bias: 3.9626e-02
# Gradient norm for fc1.weight: 9.5315e-01
# Gradient norm for fc1.bias: 4.1442e-02
# Gradient norm for fc2.weight: 1.4380e+00
# Gradient norm for fc2.bias: 1.2543e-01
# Gradient norm for conv1.weight: 3.6238e-01
# Gradient norm for conv1.bias: 6.9621e-02
# Gradient norm for conv2.weight: 6.4086e-01
# Gradient norm for conv2.bias: 5.8332e-02
# Gradient norm for conv3.weight: 4.4187e-01
# Gradient norm for conv3.bias: 3.8285e-02
# Gradient norm for fc1.weight: 8.6680e-01
# Gradient norm for fc1.bias: 3.3979e-02
# Gradient norm for fc2.weight: 1.1672e+00
# Gradient norm for fc2.bias: 9.0088e-02
# Gradient norm for conv1.weight: 4.0211e-01
# Gradient norm for conv1.bias: 1.1423e-01
# Gradient norm for conv2.weight: 1.0901e+00
# Gradient norm for conv2.bias: 9.4805e-02
# Gradient norm for conv3.weight: 6.4497e-01
# Gradient norm for conv3.bias: 5.4010e-02
# Gradient norm for fc1.weight: 7.7166e-01
# Gradient norm for fc1.bias: 3.1313e-02
# Gradient norm for fc2.weight: 1.0136e+00
# Gradient norm for fc2.bias: 7.3257e-02
# Gradient norm for conv1.weight: 3.0834e-01
# Gradient norm for conv1.bias: 9.1085e-02
# Gradient norm for conv2.weight: 8.5087e-01
# Gradient norm for conv2.bias: 7.9090e-02
# Gradient norm for conv3.weight: 6.1008e-01
# Gradient norm for conv3.bias: 5.5750e-02
# Gradient norm for fc1.weight: 8.9006e-01
# Gradient norm for fc1.bias: 4.0782e-02
# Gradient norm for fc2.weight: 1.1805e+00
# Gradient norm for fc2.bias: 1.0120e-01
# Gradient norm for conv1.weight: 7.4599e-01
# Gradient norm for conv1.bias: 2.6798e-01
# Gradient norm for conv2.weight: 2.0939e+00
# Gradient norm for conv2.bias: 2.0385e-01
# Gradient norm for conv3.weight: 1.0936e+00
# Gradient norm for conv3.bias: 1.0259e-01
# Gradient norm for fc1.weight: 1.1499e+00
# Gradient norm for fc1.bias: 5.0017e-02
# Gradient norm for fc2.weight: 1.5981e+00
# Gradient norm for fc2.bias: 1.2765e-01
# Gradient norm for conv1.weight: 2.0659e-01
# Gradient norm for conv1.bias: 9.2713e-02
# Gradient norm for conv2.weight: 6.1148e-01
# Gradient norm for conv2.bias: 7.3008e-02
# Gradient norm for conv3.weight: 4.4651e-01
# Gradient norm for conv3.bias: 4.5114e-02
# Gradient norm for fc1.weight: 9.2541e-01
# Gradient norm for fc1.bias: 3.8978e-02
# Gradient norm for fc2.weight: 1.3867e+00
# Gradient norm for fc2.bias: 1.0649e-01
# Gradient norm for conv1.weight: 2.1483e-01
# Gradient norm for conv1.bias: 3.3877e-02
# Gradient norm for conv2.weight: 4.1076e-01
# Gradient norm for conv2.bias: 2.9094e-02
# Gradient norm for conv3.weight: 3.5179e-01
# Gradient norm for conv3.bias: 2.2969e-02
# Gradient norm for fc1.weight: 7.9290e-01
# Gradient norm for fc1.bias: 2.5613e-02
# Gradient norm for fc2.weight: 1.1637e+00
# Gradient norm for fc2.bias: 7.3873e-02
# Gradient norm for conv1.weight: 5.5638e-01
# Gradient norm for conv1.bias: 1.1208e-01
# Gradient norm for conv2.weight: 1.2864e+00
# Gradient norm for conv2.bias: 8.4596e-02
# Gradient norm for conv3.weight: 7.6611e-01
# Gradient norm for conv3.bias: 4.7703e-02
# Gradient norm for fc1.weight: 1.1125e+00
# Gradient norm for fc1.bias: 4.1582e-02
# Gradient norm for fc2.weight: 1.4632e+00
# Gradient norm for fc2.bias: 1.0222e-01
# Gradient norm for conv1.weight: 6.1045e-01
# Gradient norm for conv1.bias: 1.2365e-01
# Gradient norm for conv2.weight: 1.4340e+00
# Gradient norm for conv2.bias: 9.4332e-02
# Gradient norm for conv3.weight: 8.6865e-01
# Gradient norm for conv3.bias: 4.9978e-02
# Gradient norm for fc1.weight: 1.1820e+00
# Gradient norm for fc1.bias: 3.7413e-02
# Gradient norm for fc2.weight: 1.4880e+00
# Gradient norm for fc2.bias: 8.4186e-02
# Gradient norm for conv1.weight: 8.5272e-01
# Gradient norm for conv1.bias: 2.5662e-01
# Gradient norm for conv2.weight: 2.3617e+00
# Gradient norm for conv2.bias: 1.9333e-01
# Gradient norm for conv3.weight: 1.3595e+00
# Gradient norm for conv3.bias: 9.5704e-02
# Gradient norm for fc1.weight: 1.5337e+00
# Gradient norm for fc1.bias: 5.0349e-02
# Gradient norm for fc2.weight: 2.0071e+00
# Gradient norm for fc2.bias: 1.1631e-01
# Gradient norm for conv1.weight: 5.1088e-01
# Gradient norm for conv1.bias: 1.6626e-01
# Gradient norm for conv2.weight: 1.5962e+00
# Gradient norm for conv2.bias: 1.3878e-01
# Gradient norm for conv3.weight: 1.1733e+00
# Gradient norm for conv3.bias: 9.5512e-02
# Gradient norm for fc1.weight: 1.8619e+00
# Gradient norm for fc1.bias: 6.9724e-02
# Gradient norm for fc2.weight: 2.9337e+00
# Gradient norm for fc2.bias: 1.8579e-01
# Gradient norm for conv1.weight: 4.9226e-01
# Gradient norm for conv1.bias: 1.2862e-01
# Gradient norm for conv2.weight: 1.1333e+00
# Gradient norm for conv2.bias: 9.9430e-02
# Gradient norm for conv3.weight: 7.4631e-01
# Gradient norm for conv3.bias: 5.7484e-02
# Gradient norm for fc1.weight: 1.2559e+00
# Gradient norm for fc1.bias: 4.2542e-02
# Gradient norm for fc2.weight: 1.6778e+00
# Gradient norm for fc2.bias: 1.0691e-01
# Gradient norm for conv1.weight: 1.2899e+00
# Gradient norm for conv1.bias: 4.2543e-01
# Gradient norm for conv2.weight: 3.4668e+00
# Gradient norm for conv2.bias: 3.1864e-01
# Gradient norm for conv3.weight: 1.8532e+00
# Gradient norm for conv3.bias: 1.5757e-01
# Gradient norm for fc1.weight: 1.9131e+00
# Gradient norm for fc1.bias: 7.3669e-02
# Gradient norm for fc2.weight: 2.7994e+00
# Gradient norm for fc2.bias: 1.8112e-01
# Gradient norm for conv1.weight: 4.7345e-01
# Gradient norm for conv1.bias: 2.3191e-01
# Gradient norm for conv2.weight: 1.5807e+00
# Gradient norm for conv2.bias: 1.7448e-01
# Gradient norm for conv3.weight: 1.0014e+00
# Gradient norm for conv3.bias: 9.4290e-02
# Gradient norm for fc1.weight: 1.4352e+00
# Gradient norm for fc1.bias: 5.5809e-02
# Gradient norm for fc2.weight: 1.9721e+00
# Gradient norm for fc2.bias: 1.3485e-01
# Gradient norm for conv1.weight: 3.0875e-01
# Gradient norm for conv1.bias: 4.6958e-02
# Gradient norm for conv2.weight: 4.6131e-01
# Gradient norm for conv2.bias: 4.0263e-02
# Gradient norm for conv3.weight: 4.0524e-01
# Gradient norm for conv3.bias: 3.3365e-02
# Gradient norm for fc1.weight: 1.1011e+00
# Gradient norm for fc1.bias: 3.9663e-02
# Gradient norm for fc2.weight: 1.6511e+00
# Gradient norm for fc2.bias: 1.0145e-01
# Gradient norm for conv1.weight: 2.6142e-01
# Gradient norm for conv1.bias: 6.5136e-02
# Gradient norm for conv2.weight: 6.0631e-01
# Gradient norm for conv2.bias: 4.3228e-02
# Gradient norm for conv3.weight: 4.7980e-01
# Gradient norm for conv3.bias: 3.1325e-02
# Gradient norm for fc1.weight: 1.0306e+00
# Gradient norm for fc1.bias: 3.6631e-02
# Gradient norm for fc2.weight: 1.6404e+00
# Gradient norm for fc2.bias: 1.0151e-01
# Gradient norm for conv1.weight: 2.1907e-01
# Gradient norm for conv1.bias: 4.1462e-02
# Gradient norm for conv2.weight: 5.1092e-01
# Gradient norm for conv2.bias: 3.3667e-02
# Gradient norm for conv3.weight: 4.5113e-01
# Gradient norm for conv3.bias: 2.9454e-02
# Gradient norm for fc1.weight: 1.2403e+00
# Gradient norm for fc1.bias: 4.4444e-02
# Gradient norm for fc2.weight: 1.9721e+00
# Gradient norm for fc2.bias: 1.1903e-01
# Gradient norm for conv1.weight: 8.3786e-01
# Gradient norm for conv1.bias: 2.6033e-01
# Gradient norm for conv2.weight: 2.0416e+00
# Gradient norm for conv2.bias: 1.8635e-01
# Gradient norm for conv3.weight: 1.0392e+00
# Gradient norm for conv3.bias: 8.5087e-02
# Gradient norm for fc1.weight: 1.2761e+00
# Gradient norm for fc1.bias: 4.5304e-02
# Gradient norm for fc2.weight: 1.7333e+00
# Gradient norm for fc2.bias: 1.0252e-01
# Gradient norm for conv1.weight: 4.0984e-01
# Gradient norm for conv1.bias: 1.4721e-01
# Gradient norm for conv2.weight: 1.2777e+00
# Gradient norm for conv2.bias: 1.0880e-01
# Gradient norm for conv3.weight: 7.8503e-01
# Gradient norm for conv3.bias: 5.6069e-02
# Gradient norm for fc1.weight: 1.1334e+00
# Gradient norm for fc1.bias: 3.8006e-02
# Gradient norm for fc2.weight: 1.7235e+00
# Gradient norm for fc2.bias: 9.6095e-02
# Gradient norm for conv1.weight: 4.3047e-01
# Gradient norm for conv1.bias: 1.1963e-01
# Gradient norm for conv2.weight: 1.0425e+00
# Gradient norm for conv2.bias: 9.4926e-02
# Gradient norm for conv3.weight: 7.4731e-01
# Gradient norm for conv3.bias: 5.9031e-02
# Gradient norm for fc1.weight: 1.3971e+00
# Gradient norm for fc1.bias: 4.9885e-02
# Gradient norm for fc2.weight: 2.1868e+00
# Gradient norm for fc2.bias: 1.3005e-01
# Gradient norm for conv1.weight: 3.7923e-01
# Gradient norm for conv1.bias: 8.5269e-02
# Gradient norm for conv2.weight: 8.5144e-01
# Gradient norm for conv2.bias: 6.5622e-02
# Gradient norm for conv3.weight: 6.0326e-01
# Gradient norm for conv3.bias: 4.2727e-02
# Gradient norm for fc1.weight: 1.3686e+00
# Gradient norm for fc1.bias: 4.6492e-02
# Gradient norm for fc2.weight: 2.2043e+00
# Gradient norm for fc2.bias: 1.2335e-01
# Gradient norm for conv1.weight: 7.3703e-01
# Gradient norm for conv1.bias: 2.4798e-01
# Gradient norm for conv2.weight: 1.8636e+00
# Gradient norm for conv2.bias: 1.7341e-01
# Gradient norm for conv3.weight: 1.0015e+00
# Gradient norm for conv3.bias: 8.0558e-02
# Gradient norm for fc1.weight: 1.4125e+00
# Gradient norm for fc1.bias: 4.7195e-02
# Gradient norm for fc2.weight: 2.1293e+00
# Gradient norm for fc2.bias: 1.1302e-01
# Gradient norm for conv1.weight: 4.8920e-01
# Gradient norm for conv1.bias: 1.6172e-01
# Gradient norm for conv2.weight: 1.2911e+00
# Gradient norm for conv2.bias: 1.1432e-01
# Gradient norm for conv3.weight: 7.7907e-01
# Gradient norm for conv3.bias: 5.7479e-02
# Gradient norm for fc1.weight: 1.4821e+00
# Gradient norm for fc1.bias: 4.8917e-02
# Gradient norm for fc2.weight: 2.5211e+00
# Gradient norm for fc2.bias: 1.3287e-01
# Gradient norm for conv1.weight: 4.0936e-01
# Gradient norm for conv1.bias: 1.4818e-01
# Gradient norm for conv2.weight: 1.0337e+00
# Gradient norm for conv2.bias: 1.1194e-01
# Gradient norm for conv3.weight: 6.6697e-01
# Gradient norm for conv3.bias: 6.2827e-02
# Gradient norm for fc1.weight: 1.1331e+00
# Gradient norm for fc1.bias: 4.0723e-02
# Gradient norm for fc2.weight: 1.6868e+00
# Gradient norm for fc2.bias: 1.0328e-01
# Gradient norm for conv1.weight: 2.3776e-01
# Gradient norm for conv1.bias: 6.4895e-02
# Gradient norm for conv2.weight: 6.2436e-01
# Gradient norm for conv2.bias: 6.1871e-02
# Gradient norm for conv3.weight: 5.8691e-01
# Gradient norm for conv3.bias: 5.0544e-02
# Gradient norm for fc1.weight: 1.6786e+00
# Gradient norm for fc1.bias: 5.5601e-02
# Gradient norm for fc2.weight: 2.6537e+00
# Gradient norm for fc2.bias: 1.4524e-01
# Gradient norm for conv1.weight: 5.1306e-01
# Gradient norm for conv1.bias: 9.0604e-02
# Gradient norm for conv2.weight: 1.0439e+00
# Gradient norm for conv2.bias: 8.1635e-02
# Gradient norm for conv3.weight: 7.3211e-01
# Gradient norm for conv3.bias: 5.9208e-02
# Gradient norm for fc1.weight: 1.1740e+00
# Gradient norm for fc1.bias: 4.1863e-02
# Gradient norm for fc2.weight: 1.8640e+00
# Gradient norm for fc2.bias: 1.1682e-01
# Gradient norm for conv1.weight: 4.7200e-01
# Gradient norm for conv1.bias: 1.3707e-01
# Gradient norm for conv2.weight: 1.4018e+00
# Gradient norm for conv2.bias: 1.1826e-01
# Gradient norm for conv3.weight: 9.2231e-01
# Gradient norm for conv3.bias: 7.6198e-02
# Gradient norm for fc1.weight: 1.3243e+00
# Gradient norm for fc1.bias: 4.7750e-02
# Gradient norm for fc2.weight: 2.1857e+00
# Gradient norm for fc2.bias: 1.3589e-01
# Gradient norm for conv1.weight: 3.6251e-01
# Gradient norm for conv1.bias: 7.5309e-02
# Gradient norm for conv2.weight: 6.9765e-01
# Gradient norm for conv2.bias: 5.0109e-02
# Gradient norm for conv3.weight: 4.4933e-01
# Gradient norm for conv3.bias: 2.9115e-02
# Gradient norm for fc1.weight: 9.5293e-01
# Gradient norm for fc1.bias: 2.9310e-02
# Gradient norm for fc2.weight: 1.4647e+00
# Gradient norm for fc2.bias: 7.1933e-02
# Gradient norm for conv1.weight: 3.2271e-01
# Gradient norm for conv1.bias: 8.2943e-02
# Gradient norm for conv2.weight: 8.0577e-01
# Gradient norm for conv2.bias: 6.9363e-02
# Gradient norm for conv3.weight: 6.4609e-01
# Gradient norm for conv3.bias: 4.9275e-02
# Gradient norm for fc1.weight: 1.2539e+00
# Gradient norm for fc1.bias: 4.2649e-02
# Gradient norm for fc2.weight: 1.8431e+00
# Gradient norm for fc2.bias: 1.0532e-01
# Gradient norm for conv1.weight: 6.0586e-01
# Gradient norm for conv1.bias: 1.6533e-01
# Gradient norm for conv2.weight: 1.6034e+00
# Gradient norm for conv2.bias: 1.4040e-01
# Gradient norm for conv3.weight: 1.0601e+00
# Gradient norm for conv3.bias: 8.3746e-02
# Gradient norm for fc1.weight: 1.6689e+00
# Gradient norm for fc1.bias: 5.5531e-02
# Gradient norm for fc2.weight: 2.3832e+00
# Gradient norm for fc2.bias: 1.2460e-01
# Gradient norm for conv1.weight: 4.5875e-01
# Gradient norm for conv1.bias: 1.0672e-01
# Gradient norm for conv2.weight: 1.1623e+00
# Gradient norm for conv2.bias: 9.6581e-02
# Gradient norm for conv3.weight: 8.3341e-01
# Gradient norm for conv3.bias: 6.8769e-02
# Gradient norm for fc1.weight: 1.4146e+00
# Gradient norm for fc1.bias: 5.0206e-02
# Gradient norm for fc2.weight: 2.0338e+00
# Gradient norm for fc2.bias: 1.1638e-01
# Gradient norm for conv1.weight: 6.3457e-01
# Gradient norm for conv1.bias: 8.2894e-02
# Gradient norm for conv2.weight: 1.1013e+00
# Gradient norm for conv2.bias: 6.2505e-02
# Gradient norm for conv3.weight: 6.9751e-01
# Gradient norm for conv3.bias: 3.9284e-02
# Gradient norm for fc1.weight: 1.4776e+00
# Gradient norm for fc1.bias: 4.6469e-02
# Gradient norm for fc2.weight: 2.4219e+00
# Gradient norm for fc2.bias: 1.1841e-01
# Gradient norm for conv1.weight: 4.7595e-01
# Gradient norm for conv1.bias: 9.3055e-02
# Gradient norm for conv2.weight: 1.0428e+00
# Gradient norm for conv2.bias: 7.2017e-02
# Gradient norm for conv3.weight: 7.6463e-01
# Gradient norm for conv3.bias: 4.9108e-02
# Gradient norm for fc1.weight: 1.2499e+00
# Gradient norm for fc1.bias: 3.2595e-02
# Gradient norm for fc2.weight: 1.8491e+00
# Gradient norm for fc2.bias: 7.2904e-02
# Gradient norm for conv1.weight: 4.9432e-01
# Gradient norm for conv1.bias: 1.6734e-01
# Gradient norm for conv2.weight: 1.2303e+00
# Gradient norm for conv2.bias: 1.1454e-01
# Gradient norm for conv3.weight: 7.4531e-01
# Gradient norm for conv3.bias: 5.4779e-02
# Gradient norm for fc1.weight: 1.3298e+00
# Gradient norm for fc1.bias: 4.2824e-02
# Gradient norm for fc2.weight: 2.0425e+00
# Gradient norm for fc2.bias: 1.0747e-01
# Gradient norm for conv1.weight: 4.5780e-01
# Gradient norm for conv1.bias: 1.3492e-01
# Gradient norm for conv2.weight: 1.4534e+00
# Gradient norm for conv2.bias: 1.1002e-01
# Gradient norm for conv3.weight: 1.0190e+00
# Gradient norm for conv3.bias: 6.8276e-02
# Gradient norm for fc1.weight: 1.5794e+00
# Gradient norm for fc1.bias: 4.8825e-02
# Gradient norm for fc2.weight: 2.4655e+00
# Gradient norm for fc2.bias: 1.1991e-01
# Gradient norm for conv1.weight: 6.1941e-01
# Gradient norm for conv1.bias: 8.0492e-02
# Gradient norm for conv2.weight: 9.4956e-01
# Gradient norm for conv2.bias: 5.8179e-02
# Gradient norm for conv3.weight: 5.8264e-01
# Gradient norm for conv3.bias: 3.9946e-02
# Gradient norm for fc1.weight: 1.2747e+00
# Gradient norm for fc1.bias: 4.2751e-02
# Gradient norm for fc2.weight: 2.0592e+00
# Gradient norm for fc2.bias: 1.1001e-01
# Gradient norm for conv1.weight: 5.8390e-01
# Gradient norm for conv1.bias: 1.0875e-01
# Gradient norm for conv2.weight: 1.1150e+00
# Gradient norm for conv2.bias: 8.9817e-02
# Gradient norm for conv3.weight: 7.4286e-01
# Gradient norm for conv3.bias: 6.4284e-02
# Gradient norm for fc1.weight: 1.2337e+00
# Gradient norm for fc1.bias: 4.4147e-02
# Gradient norm for fc2.weight: 1.8371e+00
# Gradient norm for fc2.bias: 1.0597e-01
# Gradient norm for conv1.weight: 5.6987e-01
# Gradient norm for conv1.bias: 1.1149e-01
# Gradient norm for conv2.weight: 1.1380e+00
# Gradient norm for conv2.bias: 1.0802e-01
# Gradient norm for conv3.weight: 7.7973e-01
# Gradient norm for conv3.bias: 7.4351e-02
# Gradient norm for fc1.weight: 1.2703e+00
# Gradient norm for fc1.bias: 4.4586e-02
# Gradient norm for fc2.weight: 2.1185e+00
# Gradient norm for fc2.bias: 1.2233e-01
# Gradient norm for conv1.weight: 2.7986e-01
# Gradient norm for conv1.bias: 1.0474e-01
# Gradient norm for conv2.weight: 6.6440e-01
# Gradient norm for conv2.bias: 8.6057e-02
# Gradient norm for conv3.weight: 5.8669e-01
# Gradient norm for conv3.bias: 5.8441e-02
# Gradient norm for fc1.weight: 1.2496e+00
# Gradient norm for fc1.bias: 4.8306e-02
# Gradient norm for fc2.weight: 1.9752e+00
# Gradient norm for fc2.bias: 1.1802e-01
# Gradient norm for conv1.weight: 2.1910e-01
# Gradient norm for conv1.bias: 6.1928e-02
# Gradient norm for conv2.weight: 5.8937e-01
# Gradient norm for conv2.bias: 4.7584e-02
# Gradient norm for conv3.weight: 5.7545e-01
# Gradient norm for conv3.bias: 3.8491e-02
# Gradient norm for fc1.weight: 1.3197e+00
# Gradient norm for fc1.bias: 4.0020e-02
# Gradient norm for fc2.weight: 2.1217e+00
# Gradient norm for fc2.bias: 1.0722e-01
# Gradient norm for conv1.weight: 6.8763e-01
# Gradient norm for conv1.bias: 2.0029e-01
# Gradient norm for conv2.weight: 1.6636e+00
# Gradient norm for conv2.bias: 1.4662e-01
# Gradient norm for conv3.weight: 9.1829e-01
# Gradient norm for conv3.bias: 7.3801e-02
# Gradient norm for fc1.weight: 1.4898e+00
# Gradient norm for fc1.bias: 5.1928e-02
# Gradient norm for fc2.weight: 2.3069e+00
# Gradient norm for fc2.bias: 1.2653e-01
# Gradient norm for conv1.weight: 3.0888e-01
# Gradient norm for conv1.bias: 1.0660e-01
# Gradient norm for conv2.weight: 7.8013e-01
# Gradient norm for conv2.bias: 7.6153e-02
# Gradient norm for conv3.weight: 4.8137e-01
# Gradient norm for conv3.bias: 3.6483e-02
# Gradient norm for fc1.weight: 8.9912e-01
# Gradient norm for fc1.bias: 2.6370e-02
# Gradient norm for fc2.weight: 1.5090e+00
# Gradient norm for fc2.bias: 7.0799e-02
# Gradient norm for conv1.weight: 6.2786e-01
# Gradient norm for conv1.bias: 1.0142e-01
# Gradient norm for conv2.weight: 1.2378e+00
# Gradient norm for conv2.bias: 8.0572e-02
# Gradient norm for conv3.weight: 8.3926e-01
# Gradient norm for conv3.bias: 5.2462e-02
# Gradient norm for fc1.weight: 1.1340e+00
# Gradient norm for fc1.bias: 3.4016e-02
# Gradient norm for fc2.weight: 1.7481e+00
# Gradient norm for fc2.bias: 8.9726e-02
# Gradient norm for conv1.weight: 8.6861e-01
# Gradient norm for conv1.bias: 2.2613e-01
# Gradient norm for conv2.weight: 1.8346e+00
# Gradient norm for conv2.bias: 1.5093e-01
# Gradient norm for conv3.weight: 9.4184e-01
# Gradient norm for conv3.bias: 6.4140e-02
# Gradient norm for fc1.weight: 1.3802e+00
# Gradient norm for fc1.bias: 4.8313e-02
# Gradient norm for fc2.weight: 2.3595e+00
# Gradient norm for fc2.bias: 1.2770e-01
# Gradient norm for conv1.weight: 5.5976e-01
# Gradient norm for conv1.bias: 1.1091e-01
# Gradient norm for conv2.weight: 1.2709e+00
# Gradient norm for conv2.bias: 8.9154e-02
# Gradient norm for conv3.weight: 7.8039e-01
# Gradient norm for conv3.bias: 5.2246e-02
# Gradient norm for fc1.weight: 9.7240e-01
# Gradient norm for fc1.bias: 3.0238e-02
# Gradient norm for fc2.weight: 1.4641e+00
# Gradient norm for fc2.bias: 7.4545e-02
# Gradient norm for conv1.weight: 4.4162e-01
# Gradient norm for conv1.bias: 1.1907e-01
# Gradient norm for conv2.weight: 1.0766e+00
# Gradient norm for conv2.bias: 8.1153e-02
# Gradient norm for conv3.weight: 6.5494e-01
# Gradient norm for conv3.bias: 3.8630e-02
# Gradient norm for fc1.weight: 1.0910e+00
# Gradient norm for fc1.bias: 3.1683e-02
# Gradient norm for fc2.weight: 1.5437e+00
# Gradient norm for fc2.bias: 7.2481e-02
# Gradient norm for conv1.weight: 3.3896e-01
# Gradient norm for conv1.bias: 5.1562e-02
# Gradient norm for conv2.weight: 6.4935e-01
# Gradient norm for conv2.bias: 4.4894e-02
# Gradient norm for conv3.weight: 5.2399e-01
# Gradient norm for conv3.bias: 3.4715e-02
# Gradient norm for fc1.weight: 1.4333e+00
# Gradient norm for fc1.bias: 5.1478e-02
# Gradient norm for fc2.weight: 2.6123e+00
# Gradient norm for fc2.bias: 1.3995e-01
# Gradient norm for conv1.weight: 6.2186e-01
# Gradient norm for conv1.bias: 1.6048e-01
# Gradient norm for conv2.weight: 1.4015e+00
# Gradient norm for conv2.bias: 1.1196e-01
# Gradient norm for conv3.weight: 7.7445e-01
# Gradient norm for conv3.bias: 5.1224e-02
# Gradient norm for fc1.weight: 1.1839e+00
# Gradient norm for fc1.bias: 3.6525e-02
# Gradient norm for fc2.weight: 2.0121e+00
# Gradient norm for fc2.bias: 9.8335e-02
# Gradient norm for conv1.weight: 5.3279e-01
# Gradient norm for conv1.bias: 2.1829e-01
# Gradient norm for conv2.weight: 1.4232e+00
# Gradient norm for conv2.bias: 1.4457e-01
# Gradient norm for conv3.weight: 8.0898e-01
# Gradient norm for conv3.bias: 6.2524e-02
# Gradient norm for fc1.weight: 1.1791e+00
# Gradient norm for fc1.bias: 3.7047e-02
# Gradient norm for fc2.weight: 1.7413e+00
# Gradient norm for fc2.bias: 8.6315e-02
# Gradient norm for conv1.weight: 7.6789e-01
# Gradient norm for conv1.bias: 9.3166e-02
# Gradient norm for conv2.weight: 1.1631e+00
# Gradient norm for conv2.bias: 6.9870e-02
# Gradient norm for conv3.weight: 6.4293e-01
# Gradient norm for conv3.bias: 3.9486e-02
# Gradient norm for fc1.weight: 9.5305e-01
# Gradient norm for fc1.bias: 3.1281e-02
# Gradient norm for fc2.weight: 1.2942e+00
# Gradient norm for fc2.bias: 7.5497e-02
# Gradient norm for conv1.weight: 4.4145e-01
# Gradient norm for conv1.bias: 1.2872e-01
# Gradient norm for conv2.weight: 1.1853e+00
# Gradient norm for conv2.bias: 1.0157e-01
# Gradient norm for conv3.weight: 7.3132e-01
# Gradient norm for conv3.bias: 5.5791e-02
# Gradient norm for fc1.weight: 1.0811e+00
# Gradient norm for fc1.bias: 3.5560e-02
# Gradient norm for fc2.weight: 1.7849e+00
# Gradient norm for fc2.bias: 9.3729e-02
# Gradient norm for conv1.weight: 3.5559e-01
# Gradient norm for conv1.bias: 7.1740e-02
# Gradient norm for conv2.weight: 9.6539e-01
# Gradient norm for conv2.bias: 6.6053e-02
# Gradient norm for conv3.weight: 7.1979e-01
# Gradient norm for conv3.bias: 4.5169e-02
# Gradient norm for fc1.weight: 1.1378e+00
# Gradient norm for fc1.bias: 3.5216e-02
# Gradient norm for fc2.weight: 1.7616e+00
# Gradient norm for fc2.bias: 8.5782e-02
# Gradient norm for conv1.weight: 5.1249e-01
# Gradient norm for conv1.bias: 1.9895e-01
# Gradient norm for conv2.weight: 1.5308e+00
# Gradient norm for conv2.bias: 1.3291e-01
# Gradient norm for conv3.weight: 9.3738e-01
# Gradient norm for conv3.bias: 6.0782e-02
# Gradient norm for fc1.weight: 1.3991e+00
# Gradient norm for fc1.bias: 4.4719e-02
# Gradient norm for fc2.weight: 2.3512e+00
# Gradient norm for fc2.bias: 1.1765e-01
# Gradient norm for conv1.weight: 7.5026e-01
# Gradient norm for conv1.bias: 2.9492e-01
# Gradient norm for conv2.weight: 2.0620e+00
# Gradient norm for conv2.bias: 1.9145e-01
# Gradient norm for conv3.weight: 1.0709e+00
# Gradient norm for conv3.bias: 7.5238e-02
# Gradient norm for fc1.weight: 1.2224e+00
# Gradient norm for fc1.bias: 3.5315e-02
# Gradient norm for fc2.weight: 1.9509e+00
# Gradient norm for fc2.bias: 8.2454e-02
# Gradient norm for conv1.weight: 6.3737e-01
# Gradient norm for conv1.bias: 1.0139e-01
# Gradient norm for conv2.weight: 9.9035e-01
# Gradient norm for conv2.bias: 7.7750e-02
# Gradient norm for conv3.weight: 6.3896e-01
# Gradient norm for conv3.bias: 5.6141e-02
# Gradient norm for fc1.weight: 1.3069e+00
# Gradient norm for fc1.bias: 4.4871e-02
# Gradient norm for fc2.weight: 1.9492e+00
# Gradient norm for fc2.bias: 9.9473e-02
# Gradient norm for conv1.weight: 1.4964e+00
# Gradient norm for conv1.bias: 5.8225e-01
# Gradient norm for conv2.weight: 3.9043e+00
# Gradient norm for conv2.bias: 3.9015e-01
# Gradient norm for conv3.weight: 1.8287e+00
# Gradient norm for conv3.bias: 1.5285e-01
# Gradient norm for fc1.weight: 1.6936e+00
# Gradient norm for fc1.bias: 6.2788e-02
# Gradient norm for fc2.weight: 2.6387e+00
# Gradient norm for fc2.bias: 1.4995e-01
# Gradient norm for conv1.weight: 1.1563e+00
# Gradient norm for conv1.bias: 3.4634e-01
# Gradient norm for conv2.weight: 2.6414e+00
# Gradient norm for conv2.bias: 2.4526e-01
# Gradient norm for conv3.weight: 1.3382e+00
# Gradient norm for conv3.bias: 1.0804e-01
# Gradient norm for fc1.weight: 1.3751e+00
# Gradient norm for fc1.bias: 4.5537e-02
# Gradient norm for fc2.weight: 2.0160e+00
# Gradient norm for fc2.bias: 1.0213e-01
# Gradient norm for conv1.weight: 3.7639e-01
# Gradient norm for conv1.bias: 1.1039e-01
# Gradient norm for conv2.weight: 9.8129e-01
# Gradient norm for conv2.bias: 9.6819e-02
# Gradient norm for conv3.weight: 6.9870e-01
# Gradient norm for conv3.bias: 5.4446e-02
# Gradient norm for fc1.weight: 1.1037e+00
# Gradient norm for fc1.bias: 3.3555e-02
# Gradient norm for fc2.weight: 1.7556e+00
# Gradient norm for fc2.bias: 7.9801e-02
# Gradient norm for conv1.weight: 5.1265e-01
# Gradient norm for conv1.bias: 1.4904e-01
# Gradient norm for conv2.weight: 1.4431e+00
# Gradient norm for conv2.bias: 1.1171e-01
# Gradient norm for conv3.weight: 9.4012e-01
# Gradient norm for conv3.bias: 6.0037e-02
# Gradient norm for fc1.weight: 1.7975e+00
# Gradient norm for fc1.bias: 5.4533e-02
# Gradient norm for fc2.weight: 2.7220e+00
# Gradient norm for fc2.bias: 1.2367e-01
# Gradient norm for conv1.weight: 1.4598e+00
# Gradient norm for conv1.bias: 5.3216e-01
# Gradient norm for conv2.weight: 4.3230e+00
# Gradient norm for conv2.bias: 3.7637e-01
# Gradient norm for conv3.weight: 2.1350e+00
# Gradient norm for conv3.bias: 1.5934e-01
# Gradient norm for fc1.weight: 1.8811e+00
# Gradient norm for fc1.bias: 6.3005e-02
# Gradient norm for fc2.weight: 3.0446e+00
# Gradient norm for fc2.bias: 1.5304e-01
# Gradient norm for conv1.weight: 8.5431e-01
# Gradient norm for conv1.bias: 2.8231e-01
# Gradient norm for conv2.weight: 2.3679e+00
# Gradient norm for conv2.bias: 1.9083e-01
# Gradient norm for conv3.weight: 1.2177e+00
# Gradient norm for conv3.bias: 8.2776e-02
# Gradient norm for fc1.weight: 1.3398e+00
# Gradient norm for fc1.bias: 3.6393e-02
# Gradient norm for fc2.weight: 1.9521e+00
# Gradient norm for fc2.bias: 8.3599e-02
# Gradient norm for conv1.weight: 5.8572e-01
# Gradient norm for conv1.bias: 2.0583e-01
# Gradient norm for conv2.weight: 1.4592e+00
# Gradient norm for conv2.bias: 1.5452e-01
# Gradient norm for conv3.weight: 8.7614e-01
# Gradient norm for conv3.bias: 8.1908e-02
# Gradient norm for fc1.weight: 1.2313e+00
# Gradient norm for fc1.bias: 4.2977e-02
# Gradient norm for fc2.weight: 2.1555e+00
# Gradient norm for fc2.bias: 1.1473e-01
# Gradient norm for conv1.weight: 8.3048e-01
# Gradient norm for conv1.bias: 3.2716e-01
# Gradient norm for conv2.weight: 2.3395e+00
# Gradient norm for conv2.bias: 2.2725e-01
# Gradient norm for conv3.weight: 1.1803e+00
# Gradient norm for conv3.bias: 9.9474e-02
# Gradient norm for fc1.weight: 1.3416e+00
# Gradient norm for fc1.bias: 4.5999e-02
# Gradient norm for fc2.weight: 2.0502e+00
# Gradient norm for fc2.bias: 1.0524e-01
#   batch 100/391  loss 1.839
# Gradient norm for conv1.weight: 1.6505e+00
# Gradient norm for conv1.bias: 5.7301e-01
# Gradient norm for conv2.weight: 4.2672e+00
# Gradient norm for conv2.bias: 3.9651e-01
# Gradient norm for conv3.weight: 2.0321e+00
# Gradient norm for conv3.bias: 1.6940e-01
# Gradient norm for fc1.weight: 2.1037e+00
# Gradient norm for fc1.bias: 7.4323e-02
# Gradient norm for fc2.weight: 3.0610e+00
# Gradient norm for fc2.bias: 1.5955e-01
# Gradient norm for conv1.weight: 9.8288e-01
# Gradient norm for conv1.bias: 3.4847e-01
# Gradient norm for conv2.weight: 2.3397e+00
# Gradient norm for conv2.bias: 2.2938e-01
# Gradient norm for conv3.weight: 1.1678e+00
# Gradient norm for conv3.bias: 9.8637e-02
# Gradient norm for fc1.weight: 1.7348e+00
# Gradient norm for fc1.bias: 6.0440e-02
# Gradient norm for fc2.weight: 2.9063e+00
# Gradient norm for fc2.bias: 1.4536e-01
# Gradient norm for conv1.weight: 4.4136e-01
# Gradient norm for conv1.bias: 1.0289e-01
# Gradient norm for conv2.weight: 1.0935e+00
# Gradient norm for conv2.bias: 9.4364e-02
# Gradient norm for conv3.weight: 6.8502e-01
# Gradient norm for conv3.bias: 5.2486e-02
# Gradient norm for fc1.weight: 9.2601e-01
# Gradient norm for fc1.bias: 3.2347e-02
# Gradient norm for fc2.weight: 1.6646e+00
# Gradient norm for fc2.bias: 8.4028e-02
# Gradient norm for conv1.weight: 1.0979e+00
# Gradient norm for conv1.bias: 3.9700e-01
# Gradient norm for conv2.weight: 3.0911e+00
# Gradient norm for conv2.bias: 2.6676e-01
# Gradient norm for conv3.weight: 1.6153e+00
# Gradient norm for conv3.bias: 1.2218e-01
# Gradient norm for fc1.weight: 1.7156e+00
# Gradient norm for fc1.bias: 6.1031e-02
# Gradient norm for fc2.weight: 2.7509e+00
# Gradient norm for fc2.bias: 1.4838e-01
# Gradient norm for conv1.weight: 6.7145e-01
# Gradient norm for conv1.bias: 2.2982e-01
# Gradient norm for conv2.weight: 1.9252e+00
# Gradient norm for conv2.bias: 1.5903e-01
# Gradient norm for conv3.weight: 1.1079e+00
# Gradient norm for conv3.bias: 7.9132e-02
# Gradient norm for fc1.weight: 1.2466e+00
# Gradient norm for fc1.bias: 4.2113e-02
# Gradient norm for fc2.weight: 2.2035e+00
# Gradient norm for fc2.bias: 1.0829e-01
# Gradient norm for conv1.weight: 1.2270e+00
# Gradient norm for conv1.bias: 4.5728e-01
# Gradient norm for conv2.weight: 3.1385e+00
# Gradient norm for conv2.bias: 2.9261e-01
# Gradient norm for conv3.weight: 1.4790e+00
# Gradient norm for conv3.bias: 1.2315e-01
# Gradient norm for fc1.weight: 1.4769e+00
# Gradient norm for fc1.bias: 5.4676e-02
# Gradient norm for fc2.weight: 2.2240e+00
# Gradient norm for fc2.bias: 1.1838e-01
# Gradient norm for conv1.weight: 6.9002e-01
# Gradient norm for conv1.bias: 2.4466e-01
# Gradient norm for conv2.weight: 1.9632e+00
# Gradient norm for conv2.bias: 1.5980e-01
# Gradient norm for conv3.weight: 1.0603e+00
# Gradient norm for conv3.bias: 7.8884e-02
# Gradient norm for fc1.weight: 1.4518e+00
# Gradient norm for fc1.bias: 5.1525e-02
# Gradient norm for fc2.weight: 2.3817e+00
# Gradient norm for fc2.bias: 1.2794e-01
# Gradient norm for conv1.weight: 7.2265e-01
# Gradient norm for conv1.bias: 1.9063e-01
# Gradient norm for conv2.weight: 1.5842e+00
# Gradient norm for conv2.bias: 1.4712e-01
# Gradient norm for conv3.weight: 9.0846e-01
# Gradient norm for conv3.bias: 8.4832e-02
# Gradient norm for fc1.weight: 1.1087e+00
# Gradient norm for fc1.bias: 4.2052e-02
# Gradient norm for fc2.weight: 1.8651e+00
# Gradient norm for fc2.bias: 1.0815e-01
# Gradient norm for conv1.weight: 8.7047e-01
# Gradient norm for conv1.bias: 3.4166e-01
# Gradient norm for conv2.weight: 2.3995e+00
# Gradient norm for conv2.bias: 2.2772e-01
# Gradient norm for conv3.weight: 1.2588e+00
# Gradient norm for conv3.bias: 1.0506e-01
# Gradient norm for fc1.weight: 1.4628e+00
# Gradient norm for fc1.bias: 5.3190e-02
# Gradient norm for fc2.weight: 2.2807e+00
# Gradient norm for fc2.bias: 1.2219e-01
# Gradient norm for conv1.weight: 9.6026e-01
# Gradient norm for conv1.bias: 4.1925e-01
# Gradient norm for conv2.weight: 2.8985e+00
# Gradient norm for conv2.bias: 2.7675e-01
# Gradient norm for conv3.weight: 1.5278e+00
# Gradient norm for conv3.bias: 1.2976e-01
# Gradient norm for fc1.weight: 1.8112e+00
# Gradient norm for fc1.bias: 6.8542e-02
# Gradient norm for fc2.weight: 3.1417e+00
# Gradient norm for fc2.bias: 1.6492e-01
# Gradient norm for conv1.weight: 5.0531e-01
# Gradient norm for conv1.bias: 1.6052e-01
# Gradient norm for conv2.weight: 1.2854e+00
# Gradient norm for conv2.bias: 1.0926e-01
# Gradient norm for conv3.weight: 8.8799e-01
# Gradient norm for conv3.bias: 6.3706e-02
# Gradient norm for fc1.weight: 1.4611e+00
# Gradient norm for fc1.bias: 5.2203e-02
# Gradient norm for fc2.weight: 2.6489e+00
# Gradient norm for fc2.bias: 1.3548e-01
# Gradient norm for conv1.weight: 5.1214e-01
# Gradient norm for conv1.bias: 2.2265e-01
# Gradient norm for conv2.weight: 1.5056e+00
# Gradient norm for conv2.bias: 1.4690e-01
# Gradient norm for conv3.weight: 8.9185e-01
# Gradient norm for conv3.bias: 7.4914e-02
# Gradient norm for fc1.weight: 1.1368e+00
# Gradient norm for fc1.bias: 4.1708e-02
# Gradient norm for fc2.weight: 1.8439e+00
# Gradient norm for fc2.bias: 1.0230e-01
# Gradient norm for conv1.weight: 2.9303e-01
# Gradient norm for conv1.bias: 1.2596e-01
# Gradient norm for conv2.weight: 8.1955e-01
# Gradient norm for conv2.bias: 9.2139e-02
# Gradient norm for conv3.weight: 5.9648e-01
# Gradient norm for conv3.bias: 5.4759e-02
# Gradient norm for fc1.weight: 1.0321e+00
# Gradient norm for fc1.bias: 4.1531e-02
# Gradient norm for fc2.weight: 1.6377e+00
# Gradient norm for fc2.bias: 9.7355e-02
# Gradient norm for conv1.weight: 3.9667e-01
# Gradient norm for conv1.bias: 6.2892e-02
# Gradient norm for conv2.weight: 9.5255e-01
# Gradient norm for conv2.bias: 4.5432e-02
# Gradient norm for conv3.weight: 5.6953e-01
# Gradient norm for conv3.bias: 2.9284e-02
# Gradient norm for fc1.weight: 8.6025e-01
# Gradient norm for fc1.bias: 2.3986e-02
# Gradient norm for fc2.weight: 1.3993e+00
# Gradient norm for fc2.bias: 6.2579e-02
# Gradient norm for conv1.weight: 1.2479e+00
# Gradient norm for conv1.bias: 2.7224e-01
# Gradient norm for conv2.weight: 2.5064e+00
# Gradient norm for conv2.bias: 1.7643e-01
# Gradient norm for conv3.weight: 1.3211e+00
# Gradient norm for conv3.bias: 8.8961e-02
# Gradient norm for fc1.weight: 1.3882e+00
# Gradient norm for fc1.bias: 4.6569e-02
# Gradient norm for fc2.weight: 2.4217e+00
# Gradient norm for fc2.bias: 1.2094e-01
# Gradient norm for conv1.weight: 7.6989e-01
# Gradient norm for conv1.bias: 2.9536e-01
# Gradient norm for conv2.weight: 2.0783e+00
# Gradient norm for conv2.bias: 1.8487e-01
# Gradient norm for conv3.weight: 1.0682e+00
# Gradient norm for conv3.bias: 8.2969e-02
# Gradient norm for fc1.weight: 1.1341e+00
# Gradient norm for fc1.bias: 4.2841e-02
# Gradient norm for fc2.weight: 1.9582e+00
# Gradient norm for fc2.bias: 1.1112e-01
# Gradient norm for conv1.weight: 5.4173e-01
# Gradient norm for conv1.bias: 1.5508e-01
# Gradient norm for conv2.weight: 1.3647e+00
# Gradient norm for conv2.bias: 1.0299e-01
# Gradient norm for conv3.weight: 7.6895e-01
# Gradient norm for conv3.bias: 5.5266e-02
# Gradient norm for fc1.weight: 9.8621e-01
# Gradient norm for fc1.bias: 3.5047e-02
# Gradient norm for fc2.weight: 1.5182e+00
# Gradient norm for fc2.bias: 8.4593e-02
# Gradient norm for conv1.weight: 4.3780e-01
# ...
# Gradient norm for fc1.weight: 1.3533e+00
# Gradient norm for fc1.bias: 5.3167e-02
# Gradient norm for fc2.weight: 2.9336e+00
# Gradient norm for fc2.bias: 1.2215e-01
# Gradient norm for conv1.weight: 1.1756e+00
# Gradient norm for conv1.bias: 3.5551e-01
# Gradient norm for conv2.weight: 1.9651e+00
# Gradient norm for conv2.bias: 1.8437e-01
# Gradient norm for conv3.weight: 1.2841e+00
# Gradient norm for conv3.bias: 9.3440e-02
# Gradient norm for fc1.weight: 1.1375e+00
# Gradient norm for fc1.bias: 4.2779e-02
# Gradient norm for fc2.weight: 2.4225e+00
# Gradient norm for fc2.bias: 9.5947e-02
# Gradient norm for conv1.weight: 1.7322e+00
# Gradient norm for conv1.bias: 4.2361e-01
# Gradient norm for conv2.weight: 1.9682e+00
# Gradient norm for conv2.bias: 1.9588e-01
# Gradient norm for conv3.weight: 1.1339e+00
# Gradient norm for conv3.bias: 9.4672e-02
# Gradient norm for fc1.weight: 1.0830e+00
# Gradient norm for fc1.bias: 4.4546e-02
# Gradient norm for fc2.weight: 2.3089e+00
# Gradient norm for fc2.bias: 1.0094e-01
# Gradient norm for conv1.weight: 1.4248e+00
# Gradient norm for conv1.bias: 3.2694e-01
# Gradient norm for conv2.weight: 2.5615e+00
# Gradient norm for conv2.bias: 2.2694e-01
# Gradient norm for conv3.weight: 1.6397e+00
# Gradient norm for conv3.bias: 1.1523e-01
# Gradient norm for fc1.weight: 1.2536e+00
# Gradient norm for fc1.bias: 4.7367e-02
# Gradient norm for fc2.weight: 2.5635e+00
# Gradient norm for fc2.bias: 1.0504e-01
# Gradient norm for conv1.weight: 1.2098e+00
# Gradient norm for conv1.bias: 3.3210e-01
# Gradient norm for conv2.weight: 1.9258e+00
# Gradient norm for conv2.bias: 1.8748e-01
# Gradient norm for conv3.weight: 1.1148e+00
# Gradient norm for conv3.bias: 7.5821e-02
# Gradient norm for fc1.weight: 8.9394e-01
# Gradient norm for fc1.bias: 3.1228e-02
# Gradient norm for fc2.weight: 1.5953e+00
# Gradient norm for fc2.bias: 6.7140e-02
# Gradient norm for conv1.weight: 1.1327e+00
# Gradient norm for conv1.bias: 2.9599e-01
# Gradient norm for conv2.weight: 1.5834e+00
# Gradient norm for conv2.bias: 1.6446e-01
# Gradient norm for conv3.weight: 1.0514e+00
# Gradient norm for conv3.bias: 8.1007e-02
# Gradient norm for fc1.weight: 9.7717e-01
# Gradient norm for fc1.bias: 3.5726e-02
# Gradient norm for fc2.weight: 1.9177e+00
# Gradient norm for fc2.bias: 8.3448e-02
# Gradient norm for conv1.weight: 1.1589e+00
# Gradient norm for conv1.bias: 4.6529e-01
# Gradient norm for conv2.weight: 2.1239e+00
# Gradient norm for conv2.bias: 2.1829e-01
# Gradient norm for conv3.weight: 1.5172e+00
# Gradient norm for conv3.bias: 1.1540e-01
# Gradient norm for fc1.weight: 1.4071e+00
# Gradient norm for fc1.bias: 5.7740e-02
# Gradient norm for fc2.weight: 2.8352e+00
# Gradient norm for fc2.bias: 1.2569e-01
# Gradient norm for conv1.weight: 1.1185e+00
# Gradient norm for conv1.bias: 4.5580e-01
# Gradient norm for conv2.weight: 1.8220e+00
# Gradient norm for conv2.bias: 1.9438e-01
# Gradient norm for conv3.weight: 1.1347e+00
# Gradient norm for conv3.bias: 8.7106e-02
# Gradient norm for fc1.weight: 1.3024e+00
# Gradient norm for fc1.bias: 5.3552e-02
# Gradient norm for fc2.weight: 2.8749e+00
# Gradient norm for fc2.bias: 1.2204e-01
# Gradient norm for conv1.weight: 1.2855e+00
# Gradient norm for conv1.bias: 5.9859e-01
# Gradient norm for conv2.weight: 2.8166e+00
# Gradient norm for conv2.bias: 2.8615e-01
# Gradient norm for conv3.weight: 1.6744e+00
# Gradient norm for conv3.bias: 1.2763e-01
# Gradient norm for fc1.weight: 1.2961e+00
# Gradient norm for fc1.bias: 5.0860e-02
# Gradient norm for fc2.weight: 2.3982e+00
# Gradient norm for fc2.bias: 9.6964e-02
# Gradient norm for conv1.weight: 9.9053e-01
# Gradient norm for conv1.bias: 2.4479e-01
# Gradient norm for conv2.weight: 1.3923e+00
# Gradient norm for conv2.bias: 1.5484e-01
# Gradient norm for conv3.weight: 1.2139e+00
# Gradient norm for conv3.bias: 1.0135e-01
# Gradient norm for fc1.weight: 1.2458e+00
# Gradient norm for fc1.bias: 5.1424e-02
# Gradient norm for fc2.weight: 2.6084e+00
# Gradient norm for fc2.bias: 1.1585e-01
# Gradient norm for conv1.weight: 1.6587e+00
# Gradient norm for conv1.bias: 2.1793e-01
# Gradient norm for conv2.weight: 1.7417e+00
# Gradient norm for conv2.bias: 1.2930e-01
# Gradient norm for conv3.weight: 1.2144e+00
# Gradient norm for conv3.bias: 8.2495e-02
# Gradient norm for fc1.weight: 1.1771e+00
# Gradient norm for fc1.bias: 4.1112e-02
# Gradient norm for fc2.weight: 2.4194e+00
# Gradient norm for fc2.bias: 9.3887e-02
# Gradient norm for conv1.weight: 2.3872e+00
# Gradient norm for conv1.bias: 5.8479e-01
# Gradient norm for conv2.weight: 2.9381e+00
# Gradient norm for conv2.bias: 2.7346e-01
# Gradient norm for conv3.weight: 1.6545e+00
# Gradient norm for conv3.bias: 1.2863e-01
# Gradient norm for fc1.weight: 1.4097e+00
# Gradient norm for fc1.bias: 5.3650e-02
# Gradient norm for fc2.weight: 2.8935e+00
# Gradient norm for fc2.bias: 1.1817e-01
# Gradient norm for conv1.weight: 8.8129e-01
# Gradient norm for conv1.bias: 3.0730e-01
# Gradient norm for conv2.weight: 1.5456e+00
# Gradient norm for conv2.bias: 1.4288e-01
# Gradient norm for conv3.weight: 1.1665e+00
# Gradient norm for conv3.bias: 8.4922e-02
# Gradient norm for fc1.weight: 1.1581e+00
# Gradient norm for fc1.bias: 4.2455e-02
# Gradient norm for fc2.weight: 2.3669e+00
# Gradient norm for fc2.bias: 9.8507e-02
# Gradient norm for conv1.weight: 1.4624e+00
# Gradient norm for conv1.bias: 4.1089e-01
# Gradient norm for conv2.weight: 1.8450e+00
# Gradient norm for conv2.bias: 1.6491e-01
# Gradient norm for conv3.weight: 1.1148e+00
# Gradient norm for conv3.bias: 7.8611e-02
# Gradient norm for fc1.weight: 1.1604e+00
# Gradient norm for fc1.bias: 4.3955e-02
# Gradient norm for fc2.weight: 2.3105e+00
# Gradient norm for fc2.bias: 9.1162e-02
# Gradient norm for conv1.weight: 9.0286e-01
# Gradient norm for conv1.bias: 1.3691e-01
# Gradient norm for conv2.weight: 1.0683e+00
# Gradient norm for conv2.bias: 8.7208e-02
# Gradient norm for conv3.weight: 8.7944e-01
# Gradient norm for conv3.bias: 5.8706e-02
# Gradient norm for fc1.weight: 8.8360e-01
# Gradient norm for fc1.bias: 2.7219e-02
# Gradient norm for fc2.weight: 1.5543e+00
# Gradient norm for fc2.bias: 5.9144e-02
# Gradient norm for conv1.weight: 1.1035e+00
# Gradient norm for conv1.bias: 3.6296e-01
# Gradient norm for conv2.weight: 1.9556e+00
# Gradient norm for conv2.bias: 1.8672e-01
# Gradient norm for conv3.weight: 1.2831e+00
# Gradient norm for conv3.bias: 9.4826e-02
# Gradient norm for fc1.weight: 1.3286e+00
# Gradient norm for fc1.bias: 4.7604e-02
# Gradient norm for fc2.weight: 2.7665e+00
# Gradient norm for fc2.bias: 1.0705e-01
#   batch 100/391  loss 0.947
# Gradient norm for conv1.weight: 1.6217e+00
# Gradient norm for conv1.bias: 3.6307e-01
# Gradient norm for conv2.weight: 2.0197e+00
# Gradient norm for conv2.bias: 1.9568e-01
# Gradient norm for conv3.weight: 1.2916e+00
# Gradient norm for conv3.bias: 1.0008e-01
# Gradient norm for fc1.weight: 1.4412e+00
# Gradient norm for fc1.bias: 5.5378e-02
# Gradient norm for fc2.weight: 2.9284e+00
# Gradient norm for fc2.bias: 1.1655e-01
# Gradient norm for conv1.weight: 1.3394e+00
# Gradient norm for conv1.bias: 2.5478e-01
# Gradient norm for conv2.weight: 1.5923e+00
# Gradient norm for conv2.bias: 1.4722e-01
# Gradient norm for conv3.weight: 1.1374e+00
# Gradient norm for conv3.bias: 8.3944e-02
# Gradient norm for fc1.weight: 1.1203e+00
# Gradient norm for fc1.bias: 3.7975e-02
# Gradient norm for fc2.weight: 2.3205e+00
# Gradient norm for fc2.bias: 8.6503e-02
# Gradient norm for conv1.weight: 9.4438e-01
# Gradient norm for conv1.bias: 3.8920e-01
# Gradient norm for conv2.weight: 1.8693e+00
# Gradient norm for conv2.bias: 1.8404e-01
# Gradient norm for conv3.weight: 1.1283e+00
# Gradient norm for conv3.bias: 7.6054e-02
# Gradient norm for fc1.weight: 9.2241e-01
# Gradient norm for fc1.bias: 2.9661e-02
# Gradient norm for fc2.weight: 1.4844e+00
# Gradient norm for fc2.bias: 6.2033e-02
# Gradient norm for conv1.weight: 1.3980e+00
# Gradient norm for conv1.bias: 5.0977e-01
# Gradient norm for conv2.weight: 2.3197e+00
# Gradient norm for conv2.bias: 2.3235e-01
# Gradient norm for conv3.weight: 1.3605e+00
# Gradient norm for conv3.bias: 1.0514e-01
# Gradient norm for fc1.weight: 1.3678e+00
# Gradient norm for fc1.bias: 5.5505e-02
# Gradient norm for fc2.weight: 2.7319e+00
# Gradient norm for fc2.bias: 1.1935e-01
# Gradient norm for conv1.weight: 1.5469e+00
# Gradient norm for conv1.bias: 5.9512e-01
# Gradient norm for conv2.weight: 2.7257e+00
# Gradient norm for conv2.bias: 2.6453e-01
# Gradient norm for conv3.weight: 1.4443e+00
# Gradient norm for conv3.bias: 1.0391e-01
# Gradient norm for fc1.weight: 1.2655e+00
# Gradient norm for fc1.bias: 5.4290e-02
# Gradient norm for fc2.weight: 2.4157e+00
# Gradient norm for fc2.bias: 1.1555e-01
# Gradient norm for conv1.weight: 8.1247e-01
# Gradient norm for conv1.bias: 2.3596e-01
# Gradient norm for conv2.weight: 1.4256e+00
# Gradient norm for conv2.bias: 1.4252e-01
# Gradient norm for conv3.weight: 9.9872e-01
# Gradient norm for conv3.bias: 8.2621e-02
# Gradient norm for fc1.weight: 1.0687e+00
# Gradient norm for fc1.bias: 4.3325e-02
# Gradient norm for fc2.weight: 2.2824e+00
# Gradient norm for fc2.bias: 1.0354e-01
# Gradient norm for conv1.weight: 1.1240e+00
# Gradient norm for conv1.bias: 2.8637e-01
# Gradient norm for conv2.weight: 1.7257e+00
# Gradient norm for conv2.bias: 1.5074e-01
# Gradient norm for conv3.weight: 1.1136e+00
# Gradient norm for conv3.bias: 7.8539e-02
# Gradient norm for fc1.weight: 9.3660e-01
# Gradient norm for fc1.bias: 3.3208e-02
# Gradient norm for fc2.weight: 1.8254e+00
# Gradient norm for fc2.bias: 6.7168e-02
# Gradient norm for conv1.weight: 1.2023e+00
# Gradient norm for conv1.bias: 3.9098e-01
# Gradient norm for conv2.weight: 1.8033e+00
# Gradient norm for conv2.bias: 1.5379e-01
# Gradient norm for conv3.weight: 1.0332e+00
# Gradient norm for conv3.bias: 6.6804e-02
# Gradient norm for fc1.weight: 8.7185e-01
# Gradient norm for fc1.bias: 2.9345e-02
# Gradient norm for fc2.weight: 1.5893e+00
# Gradient norm for fc2.bias: 6.4888e-02
# Gradient norm for conv1.weight: 8.0895e-01
# Gradient norm for conv1.bias: 1.7836e-01
# Gradient norm for conv2.weight: 9.6181e-01
# Gradient norm for conv2.bias: 9.2227e-02
# Gradient norm for conv3.weight: 7.5441e-01
# Gradient norm for conv3.bias: 5.1589e-02
# Gradient norm for fc1.weight: 7.9883e-01
# Gradient norm for fc1.bias: 2.6509e-02
# Gradient norm for fc2.weight: 1.4214e+00
# Gradient norm for fc2.bias: 5.9526e-02
# Gradient norm for conv1.weight: 1.1144e+00
# Gradient norm for conv1.bias: 2.8489e-01
# Gradient norm for conv2.weight: 1.4570e+00
# Gradient norm for conv2.bias: 1.3212e-01
# Gradient norm for conv3.weight: 9.7878e-01
# Gradient norm for conv3.bias: 7.6341e-02
# Gradient norm for fc1.weight: 1.0384e+00
# Gradient norm for fc1.bias: 4.0714e-02
# Gradient norm for fc2.weight: 2.3606e+00
# Gradient norm for fc2.bias: 9.6700e-02
# Gradient norm for conv1.weight: 9.4608e-01
# Gradient norm for conv1.bias: 1.1634e-01
# Gradient norm for conv2.weight: 1.0957e+00
# Gradient norm for conv2.bias: 8.6839e-02
# Gradient norm for conv3.weight: 8.1993e-01
# Gradient norm for conv3.bias: 5.6295e-02
# Gradient norm for fc1.weight: 8.9814e-01
# Gradient norm for fc1.bias: 3.1742e-02
# Gradient norm for fc2.weight: 1.7107e+00
# Gradient norm for fc2.bias: 6.7156e-02
# Gradient norm for conv1.weight: 8.6509e-01
# Gradient norm for conv1.bias: 1.7580e-01
# Gradient norm for conv2.weight: 1.0765e+00
# Gradient norm for conv2.bias: 1.2052e-01
# Gradient norm for conv3.weight: 9.0677e-01
# Gradient norm for conv3.bias: 8.3256e-02
# Gradient norm for fc1.weight: 9.4193e-01
# Gradient norm for fc1.bias: 3.9449e-02
# Gradient norm for fc2.weight: 2.0652e+00
# Gradient norm for fc2.bias: 8.8524e-02
# Gradient norm for conv1.weight: 8.7140e-01
# Gradient norm for conv1.bias: 2.2921e-01
# Gradient norm for conv2.weight: 1.1965e+00
# Gradient norm for conv2.bias: 1.1587e-01
# Gradient norm for conv3.weight: 8.5452e-01
# Gradient norm for conv3.bias: 5.9399e-02
# Gradient norm for fc1.weight: 8.6718e-01
# Gradient norm for fc1.bias: 2.7696e-02
# Gradient norm for fc2.weight: 1.5993e+00
# Gradient norm for fc2.bias: 6.3308e-02
# Gradient norm for conv1.weight: 6.1712e-01
# Gradient norm for conv1.bias: 1.2029e-01
# Gradient norm for conv2.weight: 1.0689e+00
# Gradient norm for conv2.bias: 8.4134e-02
# Gradient norm for conv3.weight: 9.1495e-01
# Gradient norm for conv3.bias: 5.7908e-02
# Gradient norm for fc1.weight: 1.1086e+00
# Gradient norm for fc1.bias: 4.0888e-02
# Gradient norm for fc2.weight: 2.5269e+00
# Gradient norm for fc2.bias: 1.0562e-01
# Gradient norm for conv1.weight: 1.0696e+00
# Gradient norm for conv1.bias: 2.9831e-01
# Gradient norm for conv2.weight: 1.4222e+00
# Gradient norm for conv2.bias: 1.2020e-01
# Gradient norm for conv3.weight: 9.4863e-01
# Gradient norm for conv3.bias: 6.7500e-02
# Gradient norm for fc1.weight: 1.1452e+00
# Gradient norm for fc1.bias: 4.2315e-02
# Gradient norm for fc2.weight: 2.4170e+00
# Gradient norm for fc2.bias: 9.6868e-02
# Gradient norm for conv1.weight: 8.1452e-01
# Gradient norm for conv1.bias: 2.8909e-01
# Gradient norm for conv2.weight: 1.4182e+00
# Gradient norm for conv2.bias: 1.3318e-01
# Gradient norm for conv3.weight: 8.4431e-01
# Gradient norm for conv3.bias: 5.8864e-02
# Gradient norm for fc1.weight: 7.4092e-01
# Gradient norm for fc1.bias: 2.2184e-02
# Gradient norm for fc2.weight: 1.2641e+00
# Gradient norm for fc2.bias: 4.8126e-02
# Gradient norm for conv1.weight: 7.3210e-01
# Gradient norm for conv1.bias: 2.2015e-01
# Gradient norm for conv2.weight: 1.2203e+00
# Gradient norm for conv2.bias: 1.1338e-01
# Gradient norm for conv3.weight: 8.0987e-01
# Gradient norm for conv3.bias: 5.5397e-02
# Gradient norm for fc1.weight: 8.1669e-01
# Gradient norm for fc1.bias: 2.6998e-02
# Gradient norm for fc2.weight: 1.6517e+00
# Gradient norm for fc2.bias: 6.6276e-02
# Gradient norm for conv1.weight: 1.0014e+00
# Gradient norm for conv1.bias: 2.6706e-01
# Gradient norm for conv2.weight: 1.4126e+00
# Gradient norm for conv2.bias: 1.3342e-01
# Gradient norm for conv3.weight: 9.7892e-01
# Gradient norm for conv3.bias: 6.9774e-02
# Gradient norm for fc1.weight: 9.8050e-01
# Gradient norm for fc1.bias: 3.4645e-02
# Gradient norm for fc2.weight: 1.7943e+00
# Gradient norm for fc2.bias: 6.9885e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 323
#     321 if 'ipykernel' in sys.argv[0]:
#     322     sys.argv = ['scout_opt_cifar10.py', '--gpu']
# --> 323 main()
#
# Cell In[11], line 290, in main()
#     288 print(f"\nEpoch {ep}/{args.epochs}")
#     289 start = time.time()
# --> 290 train_one_epoch(model, train_loader, criterion, opt, device)
#     291 val_loss, val_acc = evaluate(model, test_loader, criterion, device)
#     292 print(f"  val_loss={val_loss:.3f}  val_acc={val_acc:.3f}  ({time.time() - start:.1f}s)")
#
# Cell In[11], line 193, in train_one_epoch(model, loader, criterion, opt, device, log_every)
#     190     loss.backward()
#     191     return loss
# --> 193 loss = opt.step(closure)
#     195 running += loss.item()
#     196 if (i + 1) % log_every == 0:
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# Cell In[11], line 141, in ModifiedScoutOptimizer.step(self, closure)
#     138 best_scale = 0
#     140 for d in directions:
# --> 141     tracked_loss, d_dir, d_steps = self._track_direction(d, closure, self.steps)
#     142     if tracked_loss < best_loss:
#     143         best_loss = tracked_loss
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[11], line 110, in ModifiedScoutOptimizer._track_direction(self, direction, closure, max_steps)
#     108 self._apply_delta(direction, self.radius)
#     109 loss = closure()
# --> 110 if loss < best_loss:
#     111     best_loss = loss
#     112     best_step = i
#
# KeyboardInterrupt:

# %%
"""scout_opt_cifar10.py

Scout-guided optimiser demo on CIFAR-10 (lightweight CNN).

Key changes in this revision
----------------------------
1. **Removed runaway debug spam** – gradient norms are now *optional* (`--debug`) and printed only once per `log_every`.
2. **Windows/Jupyter stability** – default `num_workers=0` to dodge the lingering `_workers_status` bug; override with `--workers` if you like.
3. **Minor hygiene** – clarified comments, kept CUDA auto-detection, no logic changes to the optimiser itself.
"""

import argparse, time, pathlib, sys
from typing import List

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# ------------------------------------------------------------------ #
#  1. Model                                                          #
# ------------------------------------------------------------------ #
class SmallCNN(nn.Module):
    def __init__(self, n_classes: int = 10):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.pool  = nn.MaxPool2d(2, 2)
        self.fc1   = nn.Linear(256 * 4 * 4, 256)
        self.fc2   = nn.Linear(256, n_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # 32→16
        x = self.pool(F.relu(self.conv2(x)))  # 16→8
        x = self.pool(F.relu(self.conv3(x)))  # 8 →4
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# ------------------------------------------------------------------ #
#  2. Scout-guided Optimizer                                         #
# ------------------------------------------------------------------ #
class ModifiedScoutOptimizer(torch.optim.Optimizer):
    """Adam wrapped with periodic gradient-direction scouting."""

    def __init__(
        self,
        params,
        base_opt_cls,
        *,
        lr=3e-4,
        scout_every=100,
        scout_radius=5e-4,
        scout_steps=100,
        **base_kwargs,
    ):
        params = list(params)
        self.base = base_opt_cls(params, lr=lr, **base_kwargs)
        super().__init__(params, defaults=dict(lr=lr))
        self.s_every = scout_every
        self.radius  = scout_radius
        self.steps   = scout_steps
        self._step_id = 0
        self._params  = params

    # ---- helper --------------------------------------------------- #
    @staticmethod
    @torch.no_grad()
    def _flatten(ts: List[torch.Tensor]):
        return torch.cat([t.reshape(-1) for t in ts])

    @torch.no_grad()
    def _apply_delta(self, vec_flat: torch.Tensor, coef: float):
        off = 0
        for p in self._params:
            n = p.numel()
            p.add_(vec_flat[off : off + n].view_as(p), alpha=coef)
            off += n

    @staticmethod
    @torch.no_grad()
    def _rand_orthogonal(base: torch.Tensor):
        r = torch.randn_like(base)
        proj = (r @ base) / (base @ base + 1e-12)
        ortho = r - proj * base
        return ortho / (ortho.norm() + 1e-12)

    @torch.no_grad()
    def _track(self, direction: torch.Tensor, closure):
        """Walk up to self.steps small steps in *direction*, keep best loss."""
        best_loss, best_step = float("inf"), 0
        for step in range(1, self.steps + 1):
            self._apply_delta(direction, self.radius)
            loss = closure()
            if loss < best_loss:
                best_loss, best_step = loss, step
        # rewind to original params
        self._apply_delta(direction, -self.radius * best_step)
        return best_loss, direction

    # ---- public API ---------------------------------------------- #
    def step(self, closure=None):
        if closure is None:
            raise RuntimeError("Scout optimiser needs a closure that computes loss + backward().")

        loss = closure()  # grad on current params
        self._step_id += 1

        if self._step_id % self.s_every == 0:
            g_flat   = self._flatten([p.grad for p in self._params])
            g_norm   = g_flat.norm() + 1e-12
            g_dir    = g_flat / g_norm
            ortho    = self._rand_orthogonal(g_dir)

            cand_dirs = (g_dir, ortho, -ortho)
            best_loss, best_dir = loss.item(), None
            for d in cand_dirs:
                cand_loss, cand_dir = self._track(d, closure)
                if cand_loss < best_loss:
                    best_loss, best_dir = cand_loss, cand_dir
            if best_dir is not None:
                # replace gradient with the better direction, keep magnitude
                new_grad = best_dir * g_norm
                off = 0
                for p in self._params:
                    n = p.numel()
                    p.grad.copy_(new_grad[off : off + n].view_as(p))
                    off += n

        self.base.step()
        return loss

# ------------------------------------------------------------------ #
#  3. Training utilities                                             #
# ------------------------------------------------------------------ #
@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    tot_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        out  = model(x)
        tot_loss += criterion(out, y).item() * x.size(0)
        correct  += (out.argmax(1) == y).sum().item()
        total    += y.size(0)
    return tot_loss / total, correct / total


def train_one_epoch(model, loader, criterion, opt, device, *, log_every=100, debug=False):
    model.train()
    running = 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)

        def closure():
            opt.base.zero_grad()
            with torch.enable_grad():
                out  = model(x)
                loss = criterion(out, y)
            loss.backward()
            return loss

        loss = opt.step(closure)
        running += loss.item()

        if (i + 1) % log_every == 0:
            print(f"  batch {i+1}/{len(loader)}  loss {running/log_every:.3f}")
            running = 0.0
            if debug:
                for n, p in model.named_parameters():
                    print(f"    grad {n:20s}: {p.grad.norm():.3e}")

# ------------------------------------------------------------------ #
#  4. Baseline Adam (optional)                                       #
# ------------------------------------------------------------------ #

def run_baseline_adam(epochs, batch, lr, results):
    device   = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])
    root = pathlib.Path.home() / ".torchdata"
    train_loader = DataLoader(
        datasets.CIFAR10(root, train=True, download=True, transform=transform),
        batch_size=batch, shuffle=True, num_workers=0, pin_memory=True,
    )
    test_loader = DataLoader(
        datasets.CIFAR10(root, train=False, download=True, transform=transform),
        batch_size=256, shuffle=False, num_workers=0, pin_memory=True,
    )
    model     = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    opt       = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)

    for ep in range(1, epochs + 1):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            criterion(model(x), y).backward()
            opt.step()
        v_loss, v_acc = evaluate(model, test_loader, criterion, device)
        results["adam_loss"].append(v_loss)
        results["adam_acc"].append(v_acc)
        print(f"Adam  epoch {ep:2d}:  val_acc={v_acc*100:.1f}%  val_loss={v_loss:.3f}")

# ------------------------------------------------------------------ #
#  5. Entry point                                                    #
# ------------------------------------------------------------------ #

def main():
    p = argparse.ArgumentParser()
    p.add_argument("--epochs",     type=int,   default=50)
    p.add_argument("--batch",      type=int,   default=128)
    p.add_argument("--lr",         type=float, default=3e-4)
    p.add_argument("--scout_every",type=int,   default=100)
    p.add_argument("--scout_radius",type=float,default=5e-4)
    p.add_argument("--workers",    type=int,   default=0)
    p.add_argument("--debug",      action="store_true")
    p.add_argument("--gpu",        action="store_true")
    args, _ = p.parse_known_args()

    device = torch.device("cuda" if args.gpu and torch.cuda.is_available() else "cpu")
    print("Device:", device)

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])
    root = pathlib.Path.home() / ".torchdata"
    train_loader = DataLoader(
        datasets.CIFAR10(root, train=True, download=True, transform=transform),
        batch_size=args.batch, shuffle=True, num_workers=args.workers, pin_memory=True,
    )
    test_loader = DataLoader(
        datasets.CIFAR10(root, train=False, download=True, transform=transform),
        batch_size=256, shuffle=False, num_workers=args.workers, pin_memory=True,
    )

    model     = SmallCNN().to(device)
    criterion = nn.CrossEntropyLoss()
    scout_opt = ModifiedScoutOptimizer(
        model.parameters(), optim.Adam, lr=args.lr,
        scout_every=args.scout_every, scout_radius=args.scout_radius, scout_steps=50,
        betas=(0.9, 0.999), weight_decay=1e-4,
    )

    results = {k: [] for k in ("scout_loss","scout_acc","adam_loss","adam_acc")}

    for ep in range(1, args.epochs + 1):
        print(f"\nEpoch {ep}/{args.epochs}")
        start = time.time()
        train_one_epoch(model, train_loader, criterion, scout_opt, device, debug=args.debug)
        v_loss, v_acc = evaluate(model, test_loader, criterion, device)
        results["scout_loss"].append(v_loss)
        results["scout_acc"].append(v_acc)
        print(f"  Scout val_acc={v_acc*100:.1f}%  val_loss={v_loss:.3f}  ({time.time()-start:.1f}s)")

    torch.save(model.state_dict(), "scout_cnn.pth")
    print("Model saved → scout_cnn.pth")

    run_baseline_adam(args.epochs, args.batch, args.lr, results)

    # quick comparison
    for ep in range(args.epochs):
        print(f"Epoch {ep+1:2d}: Scout {results['scout_acc'][ep]*100:.1f}%  |  Adam {results['adam_acc'][ep]*100:.1f}%")

if __name__ == "__main__":
    if "ipykernel" in sys.argv[0]:
        sys.argv = ["scout_opt_cifar10.py", "--gpu"]
    main()
# Out:
# Device: cpu
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch 1/50
